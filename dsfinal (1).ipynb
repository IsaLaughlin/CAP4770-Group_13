# %%
import numpy as np
import pandas as pd
import requests # to make TMDB API calls
import locale # to format currency as USD
locale.setlocale( locale.LC_ALL, '' )
api_key = '07c743da178e65cad9e43897e89fc202'
import ast

# %%
fixDates = pd.read_csv('dsfinal/testDates.csv', sep=',', usecols=['release_date'], squeeze=True)
fixDates
# Out:
# 0       7/14/2007
# 1       5/19/1958
# 2       5/23/1997
# 3        9/4/2010
# 4       2/11/2005
#           ...
# 4392     8/3/2001
# 4393    8/20/2004
# 4394    12/8/1982
# 4395     2/4/2015
# 4396    9/20/1962
# Name: release_date, Length: 4397, dtype: object

# %%
train = pd.read_csv('dsfinal/train.csv')
test = pd.read_csv('dsfinal/test.csv')
test['release_date'] = fixDates
test
# Out:
#         id                              belongs_to_collection    budget  \
# 0     3001  [{'id': 34055, 'name': 'Pokémon Collection', '...         0
# 1     3002                                                NaN     88000
# 2     3003                                                NaN         0
# 3     3004                                                NaN   6800000
# 4     3005                                                NaN   2000000
# ...    ...                                                ...       ...
# 4393  7394                                                NaN  42000000
# 4394  7395  [{'id': 146534, 'name': 'Without a Paddle Coll...  19000000
# 4395  7396                                                NaN  16000000
# 4396  7397                                                NaN   2000000
# 4397  7398                                                NaN     64000
#
#                                                  genres  \
# 0     [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1     [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 4     [{'id': 36, 'name': 'History'}, {'id': 99, 'na...
# ...                                                 ...
# 4393                   [{'id': 53, 'name': 'Thriller'}]
# 4394  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4395                      [{'id': 18, 'name': 'Drama'}]
# 4396  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 4397                      [{'id': 18, 'name': 'Drama'}]
#
#                                                homepage    imdb_id  \
# 0     http://www.pokemon.com/us/movies/movie-pokemon...  tt1226251
# 1                                                   NaN  tt0051380
# 2                                                   NaN  tt0118556
# 3                http://www.sonyclassics.com/incendies/  tt1255953
# 4                                                   NaN  tt0418753
# ...                                                 ...        ...
# 4393                                                NaN  tt0218922
# 4394                                                NaN  tt0364751
# 4395                                                NaN  tt0084855
# 4396                                                NaN  tt3235888
# 4397                                                NaN  tt0056663
#
#      original_language                        original_title  \
# 0                   ja                    ディアルガVSパルキアVSダークライ
# 1                   en           Attack of the 50 Foot Woman
# 2                   en                      Addicted to Love
# 3                   fr                             Incendies
# 4                   en                    Inside Deep Throat
# ...                ...                                   ...
# 4393                en                          Original Sin
# 4394                en                      Without a Paddle
# 4395                en                           The Verdict
# 4396                en                            It Follows
# 4397                fr  Vivre sa vie: film en douze tableaux
#
#                                                overview  popularity  ...  \
# 0     Ash and friends (this time accompanied by newc...    3.851534  ...
# 1     When an abused wife grows to giant size becaus...    3.559789  ...
# 2     Good-natured astronomer Sam is devastated when...    8.085194  ...
# 3     A mother's last wishes send twins Jeanne and S...    8.596012  ...
# 4     In 1972, a seemingly typical shoestring budget...    3.217680  ...
# ...                                                 ...         ...  ...
# 4393  A young man is plunged into a life of subterfu...    9.970359  ...
# 4394  Three friends, whose lives have been drifting ...    6.046516  ...
# 4395  Frank Galvin is a down-on-his luck lawyer, red...    9.596883  ...
# 4396  For 19-year-old Jay, fall should be about scho...   20.359336  ...
# 4397  Twelve episodic tales in the life of a Parisia...   11.305910  ...
#
#                                    production_countries release_date runtime  \
# 0     [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...    7/14/2007    90.0
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...    5/19/1958    65.0
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...    5/23/1997   100.0
# 3     [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...     9/4/2010   130.0
# 4     [{'iso_3166_1': 'US', 'name': 'United States o...    2/11/2005    92.0
# ...                                                 ...          ...     ...
# 4393  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...    8/20/2004   118.0
# 4394  [{'iso_3166_1': 'US', 'name': 'United States o...    12/8/1982    95.0
# 4395  [{'iso_3166_1': 'US', 'name': 'United States o...     2/4/2015   129.0
# 4396  [{'iso_3166_1': 'US', 'name': 'United States o...    9/20/1962   100.0
# 4397           [{'iso_3166_1': 'FR', 'name': 'France'}]          NaN    85.0
#
#                                        spoken_languages    status  \
# 0     [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3     [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...  Released
# 4              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                 ...       ...
# 4393  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4394           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4395           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4396           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4397          [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
#
#                                                 tagline  \
# 0     Somewhere Between Time & Space... A Legend Is ...
# 1     A titanic beauty spreads a macabre wave of hor...
# 2             A Comedy About Lost Loves And Last Laughs
# 3     The search began at the opening of their mothe...
# 4     It was filmed in 6 days for 25 thousand dollar...
# ...                                                 ...
# 4393  This is not a love story - it's a story about ...
# 4394  The call of the wild, the thrill of adventure....
# 4395  The doctors want to settle, the Church wants t...
# 4396  It doesn't think, it doesn't feel, it doesn't ...
# 4397  The many faces of a woman trying to find herse...
#
#                              title  \
# 0     Pokémon: The Rise of Darkrai
# 1      Attack of the 50 Foot Woman
# 2                 Addicted to Love
# 3                        Incendies
# 4               Inside Deep Throat
# ...                            ...
# 4393                  Original Sin
# 4394              Without a Paddle
# 4395                   The Verdict
# 4396                    It Follows
# 4397                  Vivre Sa Vie
#
#                                                Keywords  \
# 0     [{'id': 11451, 'name': 'pok√©mon'}, {'id': 115...
# 1     [{'id': 9748, 'name': 'revenge'}, {'id': 9951,...
# 2     [{'id': 931, 'name': 'jealousy'}, {'id': 9673,...
# 3     [{'id': 378, 'name': 'prison'}, {'id': 539, 'n...
# 4     [{'id': 279, 'name': 'usa'}, {'id': 1228, 'nam...
# ...                                                 ...
# 4393  [{'id': 515, 'name': 'women'}, {'id': 572, 'na...
# 4394  [{'id': 4959, 'name': 'death of a friend'}, {'...
# 4395  [{'id': 1680, 'name': 'boston'}, {'id': 6148, ...
# 4396  [{'id': 3713, 'name': 'chase'}, {'id': 6152, '...
# 4397  [{'id': 90, 'name': 'paris'}, {'id': 490, 'nam...
#
#                                                    cast  \
# 0     [{'cast_id': 3, 'character': 'Tonio', 'credit_...
# 1     [{'cast_id': 2, 'character': 'Nancy Fowler Arc...
# 2     [{'cast_id': 11, 'character': 'Maggie', 'credi...
# 3     [{'cast_id': 6, 'character': 'Nawal', 'credit_...
# 4     [{'cast_id': 1, 'character': 'Narrator (voice)...
# ...                                                 ...
# 4393  [{'cast_id': 17, 'character': 'Julia Russell/B...
# 4394  [{'cast_id': 40, 'character': 'Dan Mott', 'cre...
# 4395  [{'cast_id': 1, 'character': 'Frank Galvin', '...
# 4396  [{'cast_id': 1, 'character': 'Jay Height', 'cr...
# 4397  [{'cast_id': 8, 'character': 'Nana Kleinfranke...
#
#                                                    crew
# 0     [{'credit_id': '52fe44e7c3a368484e03d683', 'de...
# 1     [{'credit_id': '55807805c3a3685b1300060b', 'de...
# 2     [{'credit_id': '52fe4330c3a36847f8041367', 'de...
# 3     [{'credit_id': '56478092c3a36826140043af', 'de...
# 4     [{'credit_id': '52fe44ce9251416c75041967', 'de...
# ...                                                 ...
# 4393  [{'credit_id': '52fe4330c3a36847f80412db', 'de...
# 4394  [{'credit_id': '52fe43b29251416c7501a909', 'de...
# 4395  [{'credit_id': '52fe448bc3a368484e028c55', 'de...
# 4396  [{'credit_id': '537770b20e0a261431002299', 'de...
# 4397  [{'credit_id': '52fe4306c3a36847f80349a5', 'de...
#
# [4398 rows x 22 columns]

# %%
def getRev(row):
    response = requests.get('https://api.themoviedb.org/3/find/'+ row.imdb_id + '?api_key=' + api_key +'&language=en-US&external_source=imdb_id')
    if 'movie_results' in response.json().keys():
        if len(response.json()['movie_results']) >= 1:
            tmdbid = response.json()['movie_results'][0]['id']
        else:
            return 0
    else:
        return 0
    response = requests.get('https://api.themoviedb.org/3/movie/' + str(tmdbid) + '?api_key=' +  api_key + '&language=en-US')
    if 'revenue' in response.json().keys():
        return response.json()['revenue']
    else: 
        return 0

revenues = test.apply(lambda row: getRev(row), axis = 1)
test['revenue'] = revenues

frames = [train, test]
combined = pd.concat(frames, sort = False)
combined.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0    2/20/2015    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1     8/6/2004   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2   10/10/2014   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3     3/9/2012   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4     2/5/2009   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
trainpre = train
trainpre = trainpre.drop(["homepage", "imdb_id", "popularity", "overview", "tagline", "status", "poster_path"], axis=1)
combined = combined.drop(["homepage", "imdb_id", "popularity", "overview", "tagline", "status", "poster_path"], axis=1)

# %%
trainpre['belongs_to_collection'] = trainpre['belongs_to_collection'].fillna(0)
trainpre.loc[trainpre.belongs_to_collection != '', 'has_collection'] = '1'
trainpre.loc[trainpre.belongs_to_collection == 0, 'has_collection'] = '0'
trainpre['collection'] = trainpre.apply(lambda row: ast.literal_eval(row.belongs_to_collection) if type(row.belongs_to_collection) == str else 0, axis = 1)
trainpre['collection_name'] = trainpre.apply(lambda row: row.collection[0]['name'] if type(row.collection) == list else 0, axis = 1)
trainpre['cast'] = trainpre.apply(lambda row: ast.literal_eval(row.cast) if type(row.cast) == str else 0, axis = 1)
trainpre['crew'] = trainpre.apply(lambda row: ast.literal_eval(row.crew) if type(row.crew) == str else 0, axis = 1)
trainpre['production_companies'] = trainpre.apply(lambda row: ast.literal_eval(row.production_companies) if type(row.production_companies) == str else 0, axis = 1)

# %%
combined['belongs_to_collection'] = combined['belongs_to_collection'].fillna(0)
combined.loc[combined.belongs_to_collection != '', 'has_collection'] = '1'
combined.loc[combined.belongs_to_collection == 0, 'has_collection'] = '0'
combined['collection'] = combined.apply(lambda row: ast.literal_eval(row.belongs_to_collection) if type(row.belongs_to_collection) == str else 0, axis = 1)
combined['collection_name'] = combined.apply(lambda row: row.collection[0]['name'] if type(row.collection) == list else 0, axis = 1)
combined['cast'] = combined.apply(lambda row: ast.literal_eval(row.cast) if type(row.cast) == str else 0, axis = 1)
combined['crew'] = combined.apply(lambda row: ast.literal_eval(row.crew) if type(row.crew) == str else 0, axis = 1)
combined['production_companies'] = combined.apply(lambda row: ast.literal_eval(row.production_companies) if type(row.production_companies) == str else 0, axis = 1)
combined
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                  0   3300000
# 3        4                                                  0   1200000
# 4        5                                                  0         0
# ...    ...                                                ...       ...
# 4393  7394                                                  0  42000000
# 4394  7395  [{'id': 146534, 'name': 'Without a Paddle Coll...  19000000
# 4395  7396                                                  0  16000000
# 4396  7397                                                  0   2000000
# 4397  7398                                                  0     64000
#
#                                                  genres original_language  \
# 0                        [{'id': 35, 'name': 'Comedy'}]                en
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 2                         [{'id': 18, 'name': 'Drama'}]                en
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...                hi
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...                ko
# ...                                                 ...               ...
# 4393                   [{'id': 53, 'name': 'Thriller'}]                en
# 4394  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 4395                      [{'id': 18, 'name': 'Drama'}]                en
# 4396  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...                en
# 4397                      [{'id': 18, 'name': 'Drama'}]                fr
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 4393                              Original Sin
# 4394                          Without a Paddle
# 4395                               The Verdict
# 4396                                It Follows
# 4397      Vivre sa vie: film en douze tableaux
#
#                                    production_companies  \
# 0     [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1           [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2     [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4393  [{'name': 'Intermedia Films', 'id': 763}, {'na...
# 4394  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4395  [{'name': 'Twentieth Century Fox Film Corporat...
# 4396  [{'name': 'Northern Lights Films', 'id': 8714}...
# 4397  [{'name': 'Pathé Consortium Cinéma', 'id': 220...
#
#                                    production_countries release_date  runtime  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...    2/20/2015     93.0
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...     8/6/2004    113.0
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   10/10/2014    105.0
# 3               [{'iso_3166_1': 'IN', 'name': 'India'}]     3/9/2012    122.0
# 4         [{'iso_3166_1': 'KR', 'name': 'South Korea'}]     2/5/2009    118.0
# ...                                                 ...          ...      ...
# 4393  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...    8/20/2004    118.0
# 4394  [{'iso_3166_1': 'US', 'name': 'United States o...    12/8/1982     95.0
# 4395  [{'iso_3166_1': 'US', 'name': 'United States o...     2/4/2015    129.0
# 4396  [{'iso_3166_1': 'US', 'name': 'United States o...    9/20/1962    100.0
# 4397           [{'iso_3166_1': 'FR', 'name': 'France'}]          NaN     85.0
#
#                                        spoken_languages  \
# 0              [{'iso_639_1': 'en', 'name': 'English'}]
# 1              [{'iso_639_1': 'en', 'name': 'English'}]
# 2              [{'iso_639_1': 'en', 'name': 'English'}]
# 3     [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4              [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# ...                                                 ...
# 4393  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4394           [{'iso_639_1': 'en', 'name': 'English'}]
# 4395           [{'iso_639_1': 'en', 'name': 'English'}]
# 4396           [{'iso_639_1': 'en', 'name': 'English'}]
# 4397          [{'iso_639_1': 'fr', 'name': 'Français'}]
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 4393                              Original Sin
# 4394                          Without a Paddle
# 4395                               The Verdict
# 4396                                It Follows
# 4397                              Vivre Sa Vie
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# ...                                                 ...
# 4393  [{'id': 515, 'name': 'women'}, {'id': 572, 'na...
# 4394  [{'id': 4959, 'name': 'death of a friend'}, {'...
# 4395  [{'id': 1680, 'name': 'boston'}, {'id': 6148, ...
# 4396  [{'id': 3713, 'name': 'chase'}, {'id': 6152, '...
# 4397  [{'id': 90, 'name': 'paris'}, {'id': 490, 'nam...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 4393  [{'cast_id': 17, 'character': 'Julia Russell/B...
# 4394  [{'cast_id': 40, 'character': 'Dan Mott', 'cre...
# 4395  [{'cast_id': 1, 'character': 'Frank Galvin', '...
# 4396  [{'cast_id': 1, 'character': 'Jay Height', 'cr...
# 4397  [{'cast_id': 8, 'character': 'Nana Kleinfranke...
#
#                                                    crew   revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# ...                                                 ...       ...
# 4393  [{'credit_id': '52fe4330c3a36847f80412db', 'de...  35402320
# 4394  [{'credit_id': '52fe43b29251416c7501a909', 'de...  69631118
# 4395  [{'credit_id': '52fe448bc3a368484e028c55', 'de...  53977250
# 4396  [{'credit_id': '537770b20e0a261431002299', 'de...  14674076
# 4397  [{'credit_id': '52fe4306c3a36847f80349a5', 'de...     24517
#
#      has_collection                                         collection  \
# 0                 1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1                 1  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2                 0                                                  0
# 3                 0                                                  0
# 4                 0                                                  0
# ...             ...                                                ...
# 4393              0                                                  0
# 4394              1  [{'id': 146534, 'name': 'Without a Paddle Coll...
# 4395              0                                                  0
# 4396              0                                                  0
# 4397              0                                                  0
#
#                       collection_name
# 0     Hot Tub Time Machine Collection
# 1     The Princess Diaries Collection
# 2                                   0
# 3                                   0
# 4                                   0
# ...                               ...
# 4393                                0
# 4394      Without a Paddle Collection
# 4395                                0
# 4396                                0
# 4397                                0
#
# [7398 rows x 19 columns]

# %%
def actorReturn(row):
    if type(row.cast) == list:
        if len(row.cast) >= 2:
            actors = {
                "actor1": row.cast[0]['name'],
                "actor2": row.cast[1]['name']
            }
            return actors
        elif len(row.cast) == 1:
            actors = {
                "actor1": row.cast[0]['name'],
            }
            return actors
        else:
                    return 0
    else:
        return 0
    
def returnCrew(crew):
    crewDict = {
        'Director': None,
        'Producer': None
    }
    direc = 0
    prod = 0
    for x in crew:
        #print(crewDict)
        if x['job'] == 'Director':
            crewDict['Director'] = x['name']
            direc = 1
        elif x['job'] == 'Producer':
            crewDict['Producer'] = x['name']
            prod = 1
        if direc > 0 and prod > 0:
            return crewDict
    return crewDict

# %%
trainpre['rel_actors'] = trainpre.apply(lambda row: actorReturn(row), axis =1) 
trainpre['rel_crew'] = trainpre.apply(lambda row: returnCrew(row.crew) if type(row.crew) == list else {},  axis =1)
combined['rel_actors'] = combined.apply(lambda row: actorReturn(row), axis =1) 
combined['rel_crew'] = combined.apply(lambda row: returnCrew(row.crew) if type(row.crew) == list else {},  axis =1)
combined
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                  0   3300000
# 3        4                                                  0   1200000
# 4        5                                                  0         0
# ...    ...                                                ...       ...
# 4393  7394                                                  0  42000000
# 4394  7395  [{'id': 146534, 'name': 'Without a Paddle Coll...  19000000
# 4395  7396                                                  0  16000000
# 4396  7397                                                  0   2000000
# 4397  7398                                                  0     64000
#
#                                                  genres original_language  \
# 0                        [{'id': 35, 'name': 'Comedy'}]                en
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 2                         [{'id': 18, 'name': 'Drama'}]                en
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...                hi
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...                ko
# ...                                                 ...               ...
# 4393                   [{'id': 53, 'name': 'Thriller'}]                en
# 4394  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 4395                      [{'id': 18, 'name': 'Drama'}]                en
# 4396  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...                en
# 4397                      [{'id': 18, 'name': 'Drama'}]                fr
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 4393                              Original Sin
# 4394                          Without a Paddle
# 4395                               The Verdict
# 4396                                It Follows
# 4397      Vivre sa vie: film en douze tableaux
#
#                                    production_companies  \
# 0     [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1           [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2     [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4393  [{'name': 'Intermedia Films', 'id': 763}, {'na...
# 4394  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4395  [{'name': 'Twentieth Century Fox Film Corporat...
# 4396  [{'name': 'Northern Lights Films', 'id': 8714}...
# 4397  [{'name': 'Pathé Consortium Cinéma', 'id': 220...
#
#                                    production_countries release_date  runtime  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...    2/20/2015     93.0
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...     8/6/2004    113.0
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   10/10/2014    105.0
# 3               [{'iso_3166_1': 'IN', 'name': 'India'}]     3/9/2012    122.0
# 4         [{'iso_3166_1': 'KR', 'name': 'South Korea'}]     2/5/2009    118.0
# ...                                                 ...          ...      ...
# 4393  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...    8/20/2004    118.0
# 4394  [{'iso_3166_1': 'US', 'name': 'United States o...    12/8/1982     95.0
# 4395  [{'iso_3166_1': 'US', 'name': 'United States o...     2/4/2015    129.0
# 4396  [{'iso_3166_1': 'US', 'name': 'United States o...    9/20/1962    100.0
# 4397           [{'iso_3166_1': 'FR', 'name': 'France'}]          NaN     85.0
#
#       ...                                     title  \
# 0     ...                    Hot Tub Time Machine 2
# 1     ...  The Princess Diaries 2: Royal Engagement
# 2     ...                                  Whiplash
# 3     ...                                   Kahaani
# 4     ...                                Marine Boy
# ...   ...                                       ...
# 4393  ...                              Original Sin
# 4394  ...                          Without a Paddle
# 4395  ...                               The Verdict
# 4396  ...                                It Follows
# 4397  ...                              Vivre Sa Vie
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# ...                                                 ...
# 4393  [{'id': 515, 'name': 'women'}, {'id': 572, 'na...
# 4394  [{'id': 4959, 'name': 'death of a friend'}, {'...
# 4395  [{'id': 1680, 'name': 'boston'}, {'id': 6148, ...
# 4396  [{'id': 3713, 'name': 'chase'}, {'id': 6152, '...
# 4397  [{'id': 90, 'name': 'paris'}, {'id': 490, 'nam...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 4393  [{'cast_id': 17, 'character': 'Julia Russell/B...
# 4394  [{'cast_id': 40, 'character': 'Dan Mott', 'cre...
# 4395  [{'cast_id': 1, 'character': 'Frank Galvin', '...
# 4396  [{'cast_id': 1, 'character': 'Jay Height', 'cr...
# 4397  [{'cast_id': 8, 'character': 'Nana Kleinfranke...
#
#                                                    crew   revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# ...                                                 ...       ...
# 4393  [{'credit_id': '52fe4330c3a36847f80412db', 'de...  35402320
# 4394  [{'credit_id': '52fe43b29251416c7501a909', 'de...  69631118
# 4395  [{'credit_id': '52fe448bc3a368484e028c55', 'de...  53977250
# 4396  [{'credit_id': '537770b20e0a261431002299', 'de...  14674076
# 4397  [{'credit_id': '52fe4306c3a36847f80349a5', 'de...     24517
#
#       has_collection                                         collection  \
# 0                  1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1                  1  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2                  0                                                  0
# 3                  0                                                  0
# 4                  0                                                  0
# ...              ...                                                ...
# 4393               0                                                  0
# 4394               1  [{'id': 146534, 'name': 'Without a Paddle Coll...
# 4395               0                                                  0
# 4396               0                                                  0
# 4397               0                                                  0
#
#                       collection_name  \
# 0     Hot Tub Time Machine Collection
# 1     The Princess Diaries Collection
# 2                                   0
# 3                                   0
# 4                                   0
# ...                               ...
# 4393                                0
# 4394      Without a Paddle Collection
# 4395                                0
# 4396                                0
# 4397                                0
#
#                                              rel_actors  \
# 0     {'actor1': 'Rob Corddry', 'actor2': 'Craig Rob...
# 1     {'actor1': 'Anne Hathaway', 'actor2': 'Julie A...
# 2     {'actor1': 'Miles Teller', 'actor2': 'J.K. Sim...
# 3     {'actor1': 'Vidya Balan', 'actor2': 'Nawazuddi...
# 4     {'actor1': 'Kim Kang-woo', 'actor2': 'Jo Jae-h...
# ...                                                 ...
# 4393  {'actor1': 'Angelina Jolie', 'actor2': 'Antoni...
# 4394  {'actor1': 'Seth Green', 'actor2': 'Matthew Li...
# 4395  {'actor1': 'Paul Newman', 'actor2': 'Charlotte...
# 4396  {'actor1': 'Maika Monroe', 'actor2': 'Keir Gil...
# 4397  {'actor1': 'Anna Karina', 'actor2': 'Sady Rebb...
#
#                                                rel_crew
# 0     {'Director': 'Steve Pink', 'Producer': 'Andrew...
# 1     {'Director': 'Garry Marshall', 'Producer': 'Wh...
# 2     {'Director': 'Damien Chazelle', 'Producer': 'J...
# 3     {'Director': 'Sujoy Ghosh', 'Producer': 'Sujoy...
# 4      {'Director': 'Jong-seok Yoon', 'Producer': None}
# ...                                                 ...
# 4393  {'Director': 'Michael Cristofer', 'Producer': ...
# 4394  {'Director': 'Steven Brill', 'Producer': 'Dona...
# 4395  {'Director': 'Sidney Lumet', 'Producer': 'Rich...
# 4396  {'Director': 'David Robert Mitchell', 'Produce...
# 4397  {'Director': 'Jean-Luc Godard', 'Producer': 'P...
#
# [7398 rows x 21 columns]

# %%
def unique(list1): 
    unique_list = [] 
    # traverse for all elements 
    for x in list1: 
        # check if exists in unique_list or not 
        if x not in unique_list: 
            unique_list.append(x)
    return unique_list


crew = combined['rel_crew']
directors = []
producers = []

for crewSet in crew:
    if type(crewSet) == dict:
        if 'Director' in crewSet.keys(): 
            directors.append(crewSet['Director'])
        if 'Producer' in crewSet.keys(): 
            producers.append(crewSet['Producer'])

        #producers.append(crewSet['Producer'])

#unique_directors = []
#unique_producers = []


    
#unique_directors()
#directors

# %%
result['Director']
# Out:
# 0                  Steve Pink
# 1              Garry Marshall
# 2             Damien Chazelle
# 3                 Sujoy Ghosh
# 4              Jong-seok Yoon
#                 ...
# 4393        Michael Cristofer
# 4394             Steven Brill
# 4395             Sidney Lumet
# 4396    David Robert Mitchell
# 4397          Jean-Luc Godard
# Name: Director, Length: 7398, dtype: object

# %%
 

#directorPerformance['data'] = combined.apply(lambda row: [row.rel_crew['Director'], row.revenue, row.release_date] if 'Director' in row.rel_crew.keys() else [None, None, None], axis =1) 
directorPerformance['revenue'] = combined.apply(lambda row: row.revenue if 'Director' in row.rel_crew.keys() else  None, axis =1) 
directorPerformance['Director'] = combined.apply(lambda row: row.rel_crew['Director'] if 'Director' in row.rel_crew.keys() else  None, axis =1) 
directorPerformance['date'] = combined.apply(lambda row: str(row.release_date)[-4:] if 'Director' in row.rel_crew.keys() else  None, axis =1) 

#directorPerformance = combined.apply(lambda row: [row.rel_crew['Director'], row.revenue] if 'Director' in row.rel_crew.keys() else [None, None])
#directorPerformance.head()
#direc = pd.concat(directorPerformance['date'], directorPerformance['date'], directorPerformance['date'])
frame = { 'Director': directorPerformance['Director'], 'revenue': directorPerformance['revenue'], 'date': directorPerformance['date'] } 
result = pd.DataFrame(frame) 
#directorDF['Director'] = directorPerformance['data'](lambda x: x, axis = 1)
#directorDF['revenue'] = directorPerformance(lambda x: x, axis = 1)
#directorDF['data'] = directorPerformance(lambda x: x, axis = 1)

#directorDF

# %%
directorsAndMovies = {}
def directorLists(row):
    if row.Director == None:
        return 0
    if row.date == 'nan':
        return 0
    if row.Director in directorsAndMovies.keys(): 
        directorsAndMovies[row.Director].append([int(row.date), row.revenue])
    else:
        directorsAndMovies[row.Director] = [[int(row.date), row.revenue]]
    return 1
        
meme = result.apply(lambda row: directorLists(row), axis = 1)

# %%
def Sort(sub_li): 
  
    # reverse = None (Sorts in Ascending order) 
    # key is set to sort using second element of  
    # sublist lambda has been used 
    return(sorted(sub_li, key = lambda x: x[0]))   

for key in directorsAndMovies:
    directorsAndMovies[key] = Sort(directorsAndMovies[key])
    
directorsAndMovies
# Out:
# {'Steve Pink': [[2006, 38505009.0],
#   [2010, 64572262.0],
#   [2014, 49002684.0],
#   [2015, 12314651.0]],
#  'Garry Marshall': [[1982, 30688860.0],
#   [1988, 57041866.0],
#   [1994, 6841570.0],
#   [1999, 309457509.0],
#   [2001, 165335153.0],
#   [2004, 95149435.0],
#   [2005, 0.0],
#   [2006, 26713187.0],
#   [2006, 463000000.0],
#   [2011, 0.0],
#   [2012, 0.0],
#   [2016, 48418160.0],
#   [2016, 0.0]],
#  'Damien Chazelle': [[2009, 445435700.0], [2014, 13092000.0]],
#  'Sujoy Ghosh': [[2012, 16000000.0]],
#  'Jong-seok Yoon': [[2009, 3923970.0]],
#  'Hal Sutherland': [[1987, 3261638.0]],
#  'Ole Bornedal': [[1997, 1179002.0], [2012, 85446075.0]],
#  'Jehane Noujaim': [[2004, 2586511.0]],
#  'Brian Henson': [[1996, 34327391.0], [2002, 0.0]],
#  'Christopher Guest': [[2003, 18750246.0], [2007, 0.0], [2017, 5542025.0]],
#  'John G. Avildsen': [[1976, 117235147.0],
#   [1980, 38956288.0],
#   [1981, 0.0],
#   [1986, 115103979.0],
#   [1987, 41232.0],
#   [1988, 17514553.0],
#   [1990, 119946358.0],
#   [2004, 29916207.0],
#   [2010, 19319254.0],
#   [2017, 90815558.0]],
#  'Joe Roth': [[1987, 22642033.0], [1989, 715.0], [2006, 14655628.0]],
#  'Sam Mendes': [[1997, 1108561013.0],
#   [1999, 356296601.0],
#   [2005, 96889998.0],
#   [2006, 181001478.0],
#   [2009, 14899417.0],
#   [2015, 880674609.0],
#   [2017, 75225693.0]],
#  'F. Gary Gray': [[1981, 1238764765.0],
#   [1991, 201634991.0],
#   [1995, 28215918.0],
#   [1998, 44547681.0],
#   [1998, 126690726.0],
#   [2003, 44350926.0],
#   [2003, 176070171.0],
#   [2005, 95226116.0],
#   [2013, 0.0]],
#  'Steven Spielberg': [[1952, 130358911.0],
#   [1973, 0.0],
#   [1975, 470654000.0],
#   [1977, 303788635.0],
#   [1984, 333000000.0],
#   [1985, 389925971.0],
#   [1985, 12800000.0],
#   [1989, 474171806.0],
#   [1989, 74134790.0],
#   [1991, 275293450.0],
#   [1993, 920100000.0],
#   [1997, 74000000.0],
#   [2002, 358372926.0],
#   [2004, 219417255.0],
#   [2007, 321365567.0],
#   [2007, 31755742.0],
#   [2008, 786636033.0],
#   [2008, 0.0],
#   [2009, 66700000.0],
#   [2010, 0.0],
#   [2010, 0.0],
#   [2010, 591739379.0],
#   [2011, 371940071.0],
#   [2011, 177584879.0],
#   [2012, 618638999.0],
#   [2013, 300854823.0],
#   [2015, 165478348.0],
#   [2016, 0.0],
#   [2016, 0.0]],
#  'Stevan Filipoviƒá': [[2010, 198.0]],
#  'Wes Craven': [[1960, 25504513.0],
#   [1966, 8988731.0],
#   [1977, 25000000.0],
#   [1981, 18090181.0],
#   [1988, 19595031.0],
#   [1989, 16554699.0],
#   [1995, 19800000.0],
#   [1999, 14859394.0],
#   [2000, 161834276.0],
#   [2005, 57891803.0],
#   [2005, 19294901.0],
#   [2010, 19829957.0],
#   [2011, 173046663.0],
#   [2011, 0.0],
#   [2015, 0.0]],
#  'Ralph Fiennes': [[2011, 1072602.0], [2013, 1234254.0]],
#  'Phil Traill': [[2009, 40105542.0], [2011, 1749457.0]],
#  'Louis Leterrier': [[1982, 50871113.0],
#   [2002, 43928932.0],
#   [2005, 85167639.0],
#   [2008, 0.0],
#   [2010, 232713139.0],
#   [2013, 117698894.0],
#   [2016, 25182929.0]],
#  'Stephen Hopkins': [[1986, 24804129.0],
#   [1990, 57120318.0],
#   [1991, 12136938.0],
#   [1994, 260562.0],
#   [1998, 136159423.0],
#   [2001, 22168359.0],
#   [2006, 30156002.0],
#   [2007, 62771059.0],
#   [2007, 38619405.0]],
#  'Steve Miner': [[1981, 21722776.0],
#   [1982, 36690067.0],
#   [1992, 128000000.0],
#   [1996, 2042530.0],
#   [1996, 0.0],
#   [2008, 55041738.0]],
#  'Adam Wingard': [[2001, 0.0],
#   [2011, 14347000.0],
#   [2012, 100345.0],
#   [2014, 2367161.0]],
#  'Richard Gabai': [[2006, 0.0], [2011, 17011.0]],
#  'Jonathan King': [[2006, 4947717.0]],
#  'Manny Coto': [[1992, 8403433.0], [2013, 7.0]],
#  'David Mamet': [[1940, 8112712.0],
#   [1987, 2585639.0],
#   [1994, 124693.0],
#   [1997, 13835130.0]],
#  'Michael Dowse': [[2004, 120620.0],
#   [2011, 6928068.0],
#   [2012, 6483963.0],
#   [2013, 7847000.0]],
#  'Nelson Shin': [[1986, 5849647.0]],
#  'Roger Michell': [[1995, 58785180.0],
#   [1999, 363889678.0],
#   [2002, 94935764.0],
#   [2003, 1062253.0],
#   [2006, 0.0],
#   [2012, 8887603.0],
#   [2013, 2225098.0]],
#  'Olivier Nakache': [[2004, 151530.0], [2011, 426480871.0]],
#  'Michael Haneke': [[2000, 95242.0],
#   [2001, 9801375.0],
#   [2005, 36000000.0],
#   [2007, 7938872.0],
#   [2009, 29844753.0]],
#  'Breck Eisner': [[2004, 0.0], [2005, 119269486.0], [2015, 146936910.0]],
#  'Robert Morgan': [[2014, 7171.0]],
#  'Brett Ratner': [[1998, 244386864.0],
#   [1999, 243400000.0],
#   [2001, 347325802.0],
#   [2002, 61347797.0],
#   [2006, 459359555.0],
#   [2007, 258022233.0],
#   [2009, 0.0],
#   [2011, 152930623.0]],
#  'Boaz Yakin': [[1979, 136706683.0],
#   [1985, 37095657.0],
#   [1998, 1081957.0],
#   [2008, 43967255.0],
#   [2012, 40346186.0]],
#  'Gerard Stembridge': [[2000, 151559.0]],
#  'Wolfgang Petersen': [[1945, 11511031.0],
#   [1984, 20158808.0],
#   [1985, 12303411.0],
#   [1993, 176997168.0],
#   [1995, 189859560.0],
#   [1997, 315156409.0],
#   [2000, 325756637.0],
#   [2009, 497409852.0],
#   [2009, 85000000.0],
#   [2016, 181674817.0]],
#  'Timothy A. Chey': [[2013, 92100.0]],
#  'Sam Peckinpah': [[1965, 14873.0],
#   [1969, 638641.0],
#   [1971, 3251794.0],
#   [1992, 11000000.0],
#   [1999, 22765081.0],
#   [1999, 0.0],
#   [2005, 5000000.0],
#   [2007, 6486797.0]],
#  'Billy Corben': [[2006, 163000.0]],
#  'Stuart Rosenberg': [[1967, 16217773.0],
#   [1999, 37121708.0],
#   [2009, 86432000.0]],
#  'John Schlesinger': [[1981, 939423.0],
#   [1989, 44785053.0],
#   [1990, 29381956.0],
#   [1994, 0.0],
#   [1999, 21709020.0],
#   [2000, 24362772.0]],
#  'Richard Loncraine': [[1982, 7241180.0],
#   [2007, 41512007.0],
#   [2008, 2479538.0],
#   [2013, 0.0],
#   [2014, 1020921.0]],
#  'Clare Kilner': [[2005, 47175038.0]],
#  'Giuseppe Capotondi': [[2009, 4300000.0]],
#  'Carlos Saldanha': [[2005, 260696994.0],
#   [2006, 660940780.0],
#   [2009, 886686817.0],
#   [2011, 484635760.0],
#   [2014, 500188435.0]],
#  'Quentin Tarantino': [[1960, 425368238.0],
#   [1993, 319131050.0],
#   [1994, 0.0],
#   [1997, 39673162.0],
#   [1998, 0.0],
#   [2003, 180949000.0],
#   [2009, 152159461.0],
#   [2011, 0.0],
#   [2013, 4300000.0],
#   [2015, 155760117.0]],
#  'Craig Johnson': [[2010, 5284309.0], [2017, 653951.0]],
#  'David Carson': [[1994, 120000000.0]],
#  'Christophe Van Rompaey': [[2008, 1500000.0]],
#  'Blake Edwards': [[1959, 6800000.0],
#   [1963, 10878107.0],
#   [1964, 12368234.0],
#   [1965, 25333333.0],
#   [1975, 41833347.0],
#   [1976, 33833201.0],
#   [1977, 9056073.0],
#   [1978, 49579269.0],
#   [1982, 28215453.0],
#   [1983, 4491986.0],
#   [1983, 39321715.0],
#   [1986, 6029824.0],
#   [1986, 9500000.0],
#   [1993, 2438031.0],
#   [2006, 0.0],
#   [2010, 11000000.0],
#   [2013, 4594452.0]],
#  'Charles Jarrott': [[1980, 11000000.0], [1981, 6892098.0]],
#  'Kevin Reynolds': [[1987, 264218220.0],
#   [1987, 5716080.0],
#   [1991, 390493908.0],
#   [1994, 305070.0],
#   [2000, 75395048.0],
#   [2006, 28000000.0],
#   [2016, 46069568.0]],
#  'Steve Rash': [[1978, 14363400.0],
#   [1981, 2297493.0],
#   [1987, 0.0],
#   [1993, 36448200.0],
#   [2012, 1832541.0]],
#  'Caroline Bottaro': [[2009, 1056938.0]],
#  'Joel Schumacher': [[1985, 37803872.0],
#   [1987, 32222567.0],
#   [1990, 61489265.0],
#   [1993, 40903593.0],
#   [1993, 0.0],
#   [1994, 117615211.0],
#   [1995, 154648887.0],
#   [1996, 0.0],
#   [1997, 238207122.0],
#   [1999, 96618699.0],
#   [2002, 97837138.0],
#   [2004, 0.0],
#   [2005, 77566815.0],
#   [2008, 0.0],
#   [2010, 9612469.0],
#   [2012, 0.0],
#   [2012, 0.0]],
#  'Tom Gustafson': [[2008, 119563.0]],
#  'Kevin Bray': [[1988, 0.0], [2002, 25482931.0]],
#  'Martin Campbell': [[1995, 352194034.0],
#   [1998, 250288523.0],
#   [2000, 215663859.0],
#   [2005, 142400065.0],
#   [2006, 599045960.0],
#   [2010, 74901339.0],
#   [2012, 219851172.0],
#   [2014, 0.0]],
#  'Carol Reed': [[1949, 596349.0], [1956, 14400000.0], [1982, 37402877.0]],
#  'Gregory Hoblit': [[1998, 25232289.0],
#   [2000, 68106245.0],
#   [2002, 32287044.0],
#   [2005, 0.0],
#   [2007, 91354215.0],
#   [2008, 32483410.0]],
#  'Rob Hedden': [[1989, 14000000.0]],
#  'Alexander Payne': [[2002, 105834556.0],
#   [2004, 109502303.0],
#   [2007, 153155.0],
#   [2010, 0.0],
#   [2013, 17654912.0]],
#  'Newt Arnold': [[1988, 11806119.0]],
#  'Malcolm Venville': [[2010, 204940.0]],
#  'Jia Zhangke': [[2013, 154120.0]],
#  'Robert Mulligan': [[1962, 13129846.0], [1979, 0.0], [2015, 2853801.0]],
#  'Justin Lin': [[1970, 0.0],
#   [2006, 158468292.0],
#   [2009, 363164265.0],
#   [2010, 626137675.0],
#   [2013, 0.0],
#   [2016, 343471816.0]],
#  'John Maybury': [[2005, 21126225.0]],
#  'Walter Salles': [[1998, 5596708.0],
#   [2004, 16756372.0],
#   [2014, 0.0],
#   [2017, 0.0]],
#  'John Waters': [[1972, 6000000.0],
#   [1990, 8266343.0],
#   [1994, 7820688.0],
#   [2004, 1914166.0]],
#  'V√≠t Klus√°k': [[2004, 17393.0]],
#  'Michael Miller': [[1976, 2300000.0], [2005, 0.0]],
#  'Craig Gillespie': [[2007, 11293663.0],
#   [2011, 24922237.0],
#   [2014, 38307627.0],
#   [2016, 52099090.0]],
#  'Rajiv Menon': [[2000, 500000.0]],
#  'Harold Ramis': [[1980, 39846344.0],
#   [1986, 12308521.0],
#   [1993, 70906973.0],
#   [1999, 176885658.0],
#   [2000, 90383208.0],
#   [2002, 55003135.0],
#   [2009, 62357900.0],
#   [2011, 0.0]],
#  'Burt Reynolds': [[1978, 45000000.0], [1981, 35610100.0]],
#  'Rob Zombie': [[2003, 16829545.0],
#   [2003, 0.0],
#   [2009, 0.0],
#   [2014, 80253908.0],
#   [2016, 779820.0]],
#  'Ron Shelton': [[1988, 50888000.0],
#   [1989, 19131000.0],
#   [1992, 0.0],
#   [1999, 8434146.0],
#   [2002, 9237470.0],
#   [2012, 51142659.0],
#   [2013, 0.0],
#   [2014, 53854588.0]],
#  'Anand Tucker': [[1993, 92.0], [1999, 29922472.0], [2005, 11588205.0]],
#  'Iain Softley': [[1975, 50315140.0],
#   [1995, 7563728.0],
#   [2005, 91974818.0],
#   [2008, 0.0]],
#  'Peter Hyams': [[1981, 17374595.0],
#   [1984, 40400657.0],
#   [1988, 20324096.0],
#   [1988, 0.0],
#   [1992, 10736401.0],
#   [1994, 101646581.0],
#   [1995, 64350171.0],
#   [2001, 27053815.0],
#   [2005, 5989640.0],
#   [2009, 4388563.0],
#   [2014, 211989043.0]],
#  'Laura Lau': [[2011, 13101672.0]],
#  'Frank Marshall': [[1990, 53208180.0],
#   [1993, 0.0],
#   [1995, 152022101.0],
#   [2006, 120455994.0]],
#  'Robert Benton': [[1979, 106260000.0], [1987, 5669831.0], [2007, 5741608.0]],
#  'Stanley Tong': [[1995, 32392047.0],
#   [1996, 21890845.0],
#   [2003, 0.0],
#   [2016, 254212245.0]],
#  'Niki Caro': [[1974, 45710059.0],
#   [1992, 41400000.0],
#   [2015, 0.0],
#   [2017, 13162475.0]],
#  'Jon Amiel': [[1993, 140081992.0], [2014, 0.0], [2017, 0.0]],
#  'Ferzan Ozpetek': [[2001, 215339.0],
#   [2003, 15530077.0],
#   [2003, 5260000.0],
#   [2010, 8220215.0]],
#  'Jean-Paul Rappeneau': [[1995, 15000000.0]],
#  'Steve McQueen': [[2008, 2724474.0], [2010, 0.0], [2013, 0.0]],
#  'David Lynch': [[1980, 26010864.0],
#   [1994, 7000000.0],
#   [2000, 0.0],
#   [2001, 20117339.0],
#   [2005, 8551228.0],
#   [2006, 0.0],
#   [2007, 14560247.0],
#   [2016, 849055.0],
#   [2017, 3675201.0]],
#  'Viktor Shamirov': [[2012, 14353.0], [2012, 0.0]],
#  'Fr√©d√©ric Jardin': [[2011, 3358.0]],
#  '–ê–ª–µ–∫—Å–∞–Ω–¥—Ä –ó–µ–ª—å–¥–æ–≤–∏—á': [[2011, 73000.0]],
#  'Enrique Gato': [[2004, 0.0], [2012, 23000000.0]],
#  'Dennis Hopper': [[1988, 46616067.0], [1994, 1596687.0], [1995, 1293976.0]],
#  'Craig R. Baxley': [[1988, 20256975.0], [1990, 9229401.0]],
#  'Ron Howard': [[1968, 21095683.0],
#   [1980, 57269863.0],
#   [1985, 85313124.0],
#   [1986, 36611610.0],
#   [1989, 126297830.0],
#   [1991, 152368585.0],
#   [1993, 356613439.0],
#   [1995, 355237933.0],
#   [1996, 309492681.0],
#   [2001, 313542341.0],
#   [2005, 108539911.0],
#   [2006, 0.0],
#   [2011, 67112664.0],
#   [2012, 0.0],
#   [2013, 0.0],
#   [2013, 767820459.0],
#   [2014, 69821334.0],
#   [2015, 93820758.0],
#   [2016, 220021259.0]],
#  'Ra Hee-Chan': [[2007, 14961069.0]],
#  'Daniel Barnz': [[2009, 43165571.0], [2012, 5310554.0], [2014, 0.0]],
#  'Togan G√∂kbakar': [[2008, 5330000.0], [2014, 149521495.0]],
#  'Amma Asante': [[2000, 13819139.0], [2013, 16505460.0]],
#  'Tom Vaughan': [[1983, 170000000.0], [1983, 21.0], [2010, 15134293.0]],
#  'Mel Gibson': [[1946, 120175290.0],
#   [1993, 24760338.0],
#   [1995, 210000000.0],
#   [2004, 611899420.0],
#   [2016, 0.0]],
#  'Oliver Parker': [[1999, 18535191.0], [2009, 4706919.0], [2011, 160078586.0]],
#  'George Roy Hill': [[1966, 34562222.0],
#   [1969, 102308889.0],
#   [1975, 20642922.0],
#   [1992, 29712172.0],
#   [2000, 28000000.0],
#   [2014, 159616327.0]],
#  'Barry Levinson': [[1980, 0.0],
#   [1993, 0.0],
#   [1994, 47951979.0],
#   [1996, 165615285.0],
#   [1997, 64256513.0],
#   [1997, 214015089.0],
#   [2000, 0.0],
#   [2001, 67631903.0],
#   [2002, 0.0],
#   [2002, 49114016.0],
#   [2008, 6673422.0],
#   [2011, 3020664.0],
#   [2012, 30668.0],
#   [2016, 0.0]],
#  'Nick Hurran': [[2004, 22034832.0], [2005, 0.0]],
#  'Mike Nichols': [[1979, 24911670.0],
#   [1980, 0.0],
#   [1988, 51684798.0],
#   [1988, 103173635.0],
#   [1996, 185260553.0],
#   [2007, 0.0],
#   [2010, 115505027.0],
#   [2010, 104945305.0],
#   [2011, 33736689.0],
#   [2011, 0.0]],
#  'Peter Jackson': [[1981, 956019788.0],
#   [1992, 0.0],
#   [1996, 29359216.0],
#   [2001, 871368364.0],
#   [2002, 926287400.0],
#   [2005, 550000000.0],
#   [2005, 3049135.0],
#   [2009, 93525586.0],
#   [2012, 1021103568.0],
#   [2013, 958400000.0],
#   [2015, 1118888979.0]],
#  'Malcolm D. Lee': [[1991, 34573780.0],
#   [1995, 55030051.0],
#   [2002, 41604473.0],
#   [2008, 43650785.0],
#   [2008, 71625195.0],
#   [2013, 78378744.0]],
#  'Feng Xiaogang': [[2007, 34786960.0], [2012, 311.0]],
#  'Walt Becker': [[2007, 253625427.0],
#   [2009, 92219310.0],
#   [2013, 0.0],
#   [2015, 233755553.0]],
#  'Jennifer Chambers Lynch': [[1993, 1796389.0], [2016, 1115493.0]],
#  'Sammo Hung': [[1997, 18814720.0], [2009, 0.0]],
#  'Kevin Lima': [[1999, 448000000.0], [2006, 340487652.0], [2007, 0.0]],
#  'Bob Clark': [[1981, 125728258.0],
#   [1983, 33759266.0],
#   [1984, 21435321.0],
#   [1987, 9518342.0],
#   [1990, 5585154.0],
#   [1994, 70.0],
#   [2004, 9109322.0],
#   [2007, 36450736.0],
#   [2016, 19294144.0]],
#  'Andrzej Bartkowiak': [[2000, 91036760.0],
#   [2001, 79958599.0],
#   [2003, 56489558.0],
#   [2005, 55987321.0],
#   [2009, 12764201.0]],
#  'Marc Webb': [[1995, 0.0],
#   [2000, 752215857.0],
#   [2009, 60722734.0],
#   [2014, 705717432.0]],
#  'Roger Spottiswoode': [[1983, 70611210.0],
#   [1990, 33461269.0],
#   [1997, 333011068.0],
#   [2001, 29300000.0],
#   [2003, 71079915.0],
#   [2008, 7400000.0],
#   [2008, 96085477.0],
#   [2016, 82703.0]],
#  'Matthew Robbins': [[1978, 15500000.0],
#   [1984, 0.0],
#   [1987, 65088797.0],
#   [2013, 14110013.0]],
#  'Sam Raimi': [[1981, 29400000.0],
#   [1987, 5923044.0],
#   [1990, 48878502.0],
#   [1992, 0.0],
#   [1995, 18552460.0],
#   [2000, 12008642.0],
#   [2004, 783766341.0],
#   [2007, 890871626.0],
#   [2012, 821708551.0],
#   [2013, 0.0]],
#  'Rupert Wainwright': [[1995, 50041732.0], [2005, 46201432.0]],
#  'Spike Lee': [[1988, 365134.0],
#   [1990, 16153593.0],
#   [1995, 13071518.0],
#   [1996, 5731103.0],
#   [1996, 4939939.0],
#   [1996, 0.0],
#   [1998, 21567853.0],
#   [2001, 0.0],
#   [2002, 13060843.0],
#   [2004, 0.0],
#   [2008, 9323833.0],
#   [2013, 37295445.0],
#   [2015, 185798265.0]],
#  'Declan Lowney': [[2013, 9800000.0]],
#  'Lance Daly': [[2011, 5206.0]],
#  'George Butler': [[2000, 2452566.0]],
#  'Todd Phillips': [[1999, 254455986.0],
#   [2000, 0.0],
#   [2003, 87055349.0],
#   [2004, 170268750.0],
#   [2006, 17807569.0],
#   [2009, 459270619.0],
#   [2010, 211780824.0],
#   [2013, 362000072.0],
#   [2016, 86234523.0]],
#  'David Schwimmer': [[2007, 33000000.0], [2010, 120000.0]],
#  'Rolf de Heer': [[1991, 0.0], [2006, 300000.0]],
#  'Timothy Armstrong': [[2012, 120680.0]],
#  'Hart Bochner': [[1994, 4350774.0], [2013, 21302121.0]],
#  'Adam Green': [[2010, 3065860.0], [2010, 52604.0]],
#  'Bryan Singer': [[1967, 200276000.0],
#   [1988, 0.0],
#   [2003, 407711549.0],
#   [2004, 543934787.0],
#   [2004, 23341568.0],
#   [2006, 391081192.0],
#   [2013, 197687603.0],
#   [2014, 296339527.0]],
#  'Robert Wise': [[1948, 88.0],
#   [1965, 286214286.0],
#   [1966, 20000000.0],
#   [1968, 14000000.0],
#   [1979, 139000000.0],
#   [1992, 12376563.0],
#   [2009, 0.0],
#   [2009, 0.0]],
#  'Peter Webber': [[1986, 82169884.0], [2003, 31466789.0], [2012, 3346265.0]],
#  'Bryan Buckley': [[2016, 615816.0]],
#  'Gregor Jordan': [[2003, 6585516.0], [2008, 382174.0]],
#  'Terence Young': [[1965, 141195658.0],
#   [1967, 11000000.0],
#   [2009, 78898765.0],
#   [2010, 59600000.0]],
#  'Matthew Ross': [[2016, 9188.0]],
#  'Alan Myerson': [[1981, 26279000.0], [1988, 19510371.0]],
#  'Bong Joon-ho': [[2010, 0.0], [2013, 86758912.0], [2016, 0.0]],
#  'Brian Levant': [[1974, 97918663.0],
#   [1990, 45236543.0],
#   [1992, 147214049.0],
#   [1996, 129832389.0],
#   [2000, 59468275.0],
#   [2014, 341631208.0]],
#  'John Stockwell': [[1992, 0.0],
#   [1994, 51842679.0],
#   [2001, 16929123.0],
#   [2012, 432274.0]],
#  'Kieth Merrill': [[1980, 18.0]],
#  'Will Allen': [[2016, 16905.0]],
#  'Bernard Rose': [[1988, 241.0],
#   [1997, 791830.0],
#   [1998, 25792310.0],
#   [2010, 850994.0],
#   [2013, 11294.0]],
#  'Rob Cohen': [[1973, 401128639.0],
#   [2000, 0.0],
#   [2001, 207283925.0],
#   [2005, 76932943.0],
#   [2009, 159212469.0],
#   [2012, 30353232.0],
#   [2013, 277448382.0],
#   [2015, 52425855.0],
#   [2016, 63513743.0],
#   [2016, 115267375.0]],
#  'William Lustig': [[1983, 5091888.0]],
#  'Donovan Cook': [[2002, 109862682.0]],
#  'Aleksei Sidorov': [[2005, 8262833.0]],
#  'Boaz Davidson': [[1994, 447784.0], [2007, 0.0]],
#  'Stephen T. Kay': [[2000, 19412993.0], [2005, 67192859.0]],
#  'Adam Rapp': [[2006, 113783.0]],
#  'Genevi√®ve Robert': [[1988, 12277096.0]],
#  'Lynn Shelton': [[1964, 0.0], [2011, 3200000.0], [2013, 35022.0]],
#  'Wes Anderson': [[1983, 0.0],
#   [1991, 68263166.0],
#   [1996, 560069.0],
#   [1998, 17096053.0],
#   [2001, 71441250.0],
#   [2004, 34808403.0],
#   [2007, 24377151.0],
#   [2009, 46471023.0]],
#  'John Derek': [[1981, 36565280.0], [1984, 0.0], [1989, 25000.0]],
#  'Godfrey Reggio': [[1982, 1723872.0], [1988, 589244.0], [2002, 13308.0]],
#  'Scott Derrickson': [[1995, 77712439.0],
#   [1998, 0.0],
#   [2005, 144216468.0],
#   [2010, 0.0]],
#  'George Miller': [[1954, 150406466.0],
#   [1981, 24600832.0],
#   [1985, 0.0],
#   [1987, 0.0],
#   [1992, 7286388.0],
#   [2002, 29450919.0],
#   [2006, 384335608.0],
#   [2012, 69131860.0],
#   [2014, 100000000.0],
#   [2015, 378858340.0]],
#  'Jerry Paris': [[1985, 55600000.0], [1986, 43579163.0]],
#  'Jack Smight': [[1966, 12000000.0], [1974, 47000000.0], [2005, 8720000.0]],
#  'William A. Graham': [[1991, 2807854.0]],
#  'Stephan Elliott': [[1994, 11220670.0], [2011, 29007412.0]],
#  'Walter Hill': [[1972, 0.0],
#   [1979, 22490039.0],
#   [1982, 78868508.0],
#   [1989, 7237794.0],
#   [1990, 153518974.0],
#   [1996, 47267001.0],
#   [2000, 14828081.0],
#   [2002, 12398628.0],
#   [2002, 34994648.0],
#   [2003, 5000000.0],
#   [2003, 0.0],
#   [2004, 0.0],
#   [2005, 45833132.0],
#   [2012, 5738952.0],
#   [2013, 9489829.0]],
#  'Tom DeCerchio': [[1997, 532654.0]],
#  'Ted Kotcheff': [[1979, 26079312.0],
#   [1982, 125212904.0],
#   [1982, 263635.0],
#   [1983, 27900000.0],
#   [1989, 30218387.0],
#   [1992, 6132924.0]],
#  'John Glen': [[1977, 187500000.0],
#   [1981, 195312802.0],
#   [1985, 152427960.0],
#   [1987, 191185897.0],
#   [1989, 156167015.0],
#   [1992, 8251071.0]],
#  "Gavin O'Connor": [[1999, 0.0],
#   [2004, 64445708.0],
#   [2008, 31148328.0],
#   [2008, 1397284.0],
#   [2011, 23057115.0],
#   [2016, 0.0]],
#  'Peter Mullan': [[1998, 49501.0], [2002, 20957001.0]],
#  'Chris Columbus': [[1978, 15345201.0],
#   [1987, 0.0],
#   [1990, 476684675.0],
#   [1991, 21830957.0],
#   [1994, 976475550.0],
#   [2000, 358991681.0],
#   [2002, 876688482.0],
#   [2005, 31670620.0],
#   [2010, 226497209.0],
#   [2012, 441286195.0],
#   [2014, 69660733.0],
#   [2014, 0.0],
#   [2015, 243637091.0]],
#  'Takashi Miike': [[1983, 12756.0], [2007, 2725258.0], [2010, 17555141.0]],
#  'Frank Coraci': [[2004, 72178895.0],
#   [2004, 185991646.0],
#   [2006, 237681299.0],
#   [2010, 0.0],
#   [2011, 169852759.0],
#   [2014, 123494610.0],
#   [2015, 123306987.0]],
#  'Richard A. Colla': [[1997, 161001698.0]],
#  'Mike Clattenburg': [[2006, 3833507.0]],
#  'Tod Browning': [[1931, 1012189.0], [2009, 704000.0], [2028, 921000.0]],
#  'Andrew Stanton': [[1992, 940335536.0],
#   [2008, 521311860.0],
#   [2012, 284139100.0]],
#  'Tyler Perry': [[1985, 41939392.0],
#   [1991, 0.0],
#   [1995, 37000000.0],
#   [2006, 57231524.0],
#   [2007, 31609243.0],
#   [2009, 90508336.0],
#   [2010, 55184721.0],
#   [2013, 53213633.0],
#   [2014, 16337881.0]],
#  'Kevin Yagher': [[1996, 16675000.0]],
#  'Kirk Jones': [[2007, 122489822.0], [2012, 79700000.0], [2016, 88923251.0]],
#  'Mandie Fletcher': [[2016, 37915971.0]],
#  'Sam Firstenberg': [[1983, 13168027.0], [1985, 10499694.0]],
#  'Todd Solondz': [[1998, 2807390.0], [2009, 744816.0]],
#  'Majid Majidi': [[1997, 900000.0], [2008, 115605.0]],
#  'Armand Mastroianni': [[1988, 136203.0]],
#  'Clark Johnson': [[2003, 116643346.0], [2006, 77920346.0]],
#  'Brian Robbins': [[1956, 0.0],
#   [1996, 0.0],
#   [2000, 12372410.0],
#   [2007, 95673607.0],
#   [2012, 22044277.0],
#   [2014, 50650079.0]],
#  'Micha√´l R. Roskam': [[2014, 19054534.0]],
#  'Gary Winick': [[1983, 96455697.0],
#   [1993, 114663461.0],
#   [2002, 2891288.0],
#   [2006, 144000000.0]],
#  'Julien Temple': [[1988, 3916303.0]],
#  'Jimmy Hayward': [[2010, 0.0], [2013, 110000000.0]],
#  'David Silverman': [[2007, 527068851.0]],
#  'Howard Storm': [[1985, 10000000.0]],
#  'Jerry Jameson': [[2005, 30000000.0], [2015, 2801508.0]],
#  'Carl Franklin': [[1992, 1543112.0],
#   [2002, 63781810.0],
#   [2002, 0.0],
#   [2003, 55495563.0],
#   [2013, 1553826.0]],
#  'Bryan Spicer': [[1995, 66000000.0], [1997, 31611225.0], [2009, 0.0]],
#  'John Flynn': [[1987, 4278150.0],
#   [1991, 39673161.0],
#   [1994, 4352094.0],
#   [2003, 22099847.0]],
#  'Joe Johnston': [[1985, 222724172.0],
#   [1995, 262797249.0],
#   [1996, 62000000.0],
#   [2004, 108103450.0],
#   [2004, 368780809.0],
#   [2011, 370569774.0]],
#  'Anthony Waller': [[1995, 1.0], [1997, 26570463.0]],
#  'Darrell James Roodt': [[1984, 676525.0],
#   [1993, 3418141.0],
#   [1997, 3028094.0]],
#  'Prabhu Deva': [[2007, 0.0], [2012, 31000000.0]],
#  'Ariel Vromen': [[2002, 14708696.0], [2012, 1969193.0]],
#  'Seth Gordon': [[2007, 177856751.0],
#   [2008, 163733697.0],
#   [2013, 173965010.0],
#   [2015, 0.0]],
#  'Ry≈´ichi Yagi': [[2014, 83061158.0]],
#  'Ivan Reitman': [[1981, 85300000.0],
#   [1984, 295212467.0],
#   [1988, 216614388.0],
#   [1989, 215394738.0],
#   [1994, 37000000.0],
#   [1998, 164000000.0],
#   [2001, 98376292.0],
#   [2006, 60896147.0],
#   [2011, 147780440.0],
#   [2012, 63000000.0],
#   [2013, 28831145.0],
#   [2016, 201957688.0]],
#  'Peter Hald': [[1980, 5010362.0], [1989, 8646157.0]],
#  'Stacy Peralta': [[2004, 3166000.0]],
#  'Lu Chuan': [[2009, 10652498.0]],
#  'Dale Launer': [[1992, 754935.0]],
#  'Keith Bearden': [[2010, 31649.0]],
#  'Paul Verhoeven': [[1980, 190213455.0],
#   [1987, 0.0],
#   [1990, 261317921.0],
#   [1992, 352927224.0],
#   [1997, 121214377.0],
#   [1998, 26193068.0],
#   [2000, 2341534.0],
#   [2013, 0.0]],
#  'Gary Gulman': [[2016, 500.0]],
#  'Patrick Lussier': [[1970, 102836002.0],
#   [2000, 33000337.0],
#   [2011, 28931401.0]],
#  'Lone Scherfig': [[1997, 2146041.0],
#   [2009, 26096852.0],
#   [2011, 59389433.0],
#   [2017, 12173470.0]],
#  'James Ivory': [[1967, 1985001.0],
#   [1992, 25966555.0],
#   [1993, 23237911.0],
#   [1995, 2474000.0],
#   [2000, 1782005.0],
#   [2012, 12991996.0],
#   [2014, 20966644.0]],
#  'Victor Nunez': [[1993, 1001437.0]],
#  'Ilisa Barbash': [[2009, 206728.0]],
#  'James Gray': [[1954, 5867686.0],
#   [2007, 0.0],
#   [2008, 3148182.0],
#   [2016, 8574339.0]],
#  'Robert Shaye': [[2007, 27297451.0]],
#  'Gilbert Adler': [[1996, 5600000.0]],
#  'Luis Garc√≠a Berlanga': [[1978, 1622164.0]],
#  'Jerry Zucker': [[1986, 71624879.0],
#   [1987, 85498534.0],
#   [1988, 20458340.0],
#   [1990, 505000000.0],
#   [1992, 0.0],
#   [1995, 127600435.0]],
#  'Charles Stone III': [[2002, 57588485.0],
#   [2002, 3090862.0],
#   [2004, 21800302.0]],
#  'Jim Kouf': [[1997, 5790448.0]],
#  'Dan St. Pierre': [[2006, 16627188.0], [2013, 18662027.0]],
#  'Mamoru Hosoda': [[1950, 3800000.0], [2009, 80768.0], [2012, 490643.0]],
#  'Jodie Foster': [[1995, 17519169.0], [2011, 970816.0], [2016, 93282604.0]],
#  'Stan Dragoti': [[1979, 43885000.0], [1989, 12065892.0], [2016, 64783827.0]],
#  'Sean Anders': [[1987, 107670357.0],
#   [1993, 0.0],
#   [2008, 18755936.0],
#   [2015, 242786137.0]],
#  'Chuck Russell': [[1988, 8247943.0],
#   [1994, 351583407.0],
#   [1996, 242295562.0],
#   [2002, 165333180.0],
#   [2014, 44793222.0]],
#  'Oliver Hirschbiegel': [[1978, 21766271.0],
#   [2004, 92180910.0],
#   [2007, 15071514.0],
#   [2015, 147315.0]],
#  'Dominic Sena': [[1981, 237202299.0],
#   [1998, 12206028.0],
#   [2001, 147080413.0],
#   [2010, 2395231.0],
#   [2011, 0.0]],
#  'John Guillermin': [[1965, 4711220.0],
#   [1976, 90614445.0],
#   [1978, 14560084.0],
#   [1980, 0.0],
#   [1996, 0.0],
#   [1998, 5778353.0]],
#  'Thomas Gilou': [[1997, 29456000.0], [1998, 40924982.0], [2001, 42700000.0]],
#  'Renny Harlin': [[1981, 21148829.0],
#   [1982, 0.0],
#   [1993, 255000211.0],
#   [1993, 354704.0],
#   [1995, 10017322.0],
#   [1996, 89456761.0],
#   [1996, 0.0],
#   [1999, 73648228.0],
#   [2001, 54744738.0],
#   [2004, 78000586.0],
#   [2009, 17280326.0],
#   [2011, 37597471.0],
#   [2013, 17479.0],
#   [2015, 0.0],
#   [2016, 0.0],
#   [2017, 20423389.0]],
#  'Jay Chandrasekhar': [[1978, 110803676.0],
#   [2001, 18492362.0],
#   [2004, 5001655.0],
#   [2006, 19179969.0]],
#  'Ivan Vyrypaev': [[2012, 30292.0], [2015, 2209023.0]],
#  'Jun Lana': [[2012, 34659.0]],
#  'Jason Bateman': [[2013, 7800000.0], [2016, 262921.0]],
#  'Baltasar Korm√°kur': [[1994, 63100000.0],
#   [1999, 0.0],
#   [2002, 131940411.0],
#   [2015, 203427584.0]],
#  'Robert D. Webb': [[1956, 9000000.0]],
#  'Mamoru Oshii': [[1991, 0.0], [1995, 2287714.0], [1998, 0.0]],
#  'Santosh Sivan': [[1998, 140021.0], [2013, 0.0]],
#  'Daniel Petrie': [[1964, 3910019.0],
#   [1982, 20225989.0],
#   [1987, 0.0],
#   [1988, 187349.0],
#   [2014, 0.0]],
#  'Barry Sonnenfeld': [[1963, 115101622.0],
#   [1966, 624026776.0],
#   [1980, 8493890.0],
#   [1983, 222104681.0],
#   [1991, 441818803.0],
#   [2004, 191502426.0],
#   [2006, 87528173.0],
#   [2008, 48919043.0],
#   [2013, 11146270.0],
#   [2015, 589390539.0],
#   [2016, 57814445.0]],
#  'Tran Anh Hung': [[2010, 17636261.0]],
#  'Steve De Jarnatt': [[1985, 1145404.0], [1987, 14000.0]],
#  'David Gordon Green': [[1944, 2365467.0],
#   [1966, 26121638.0],
#   [1983, 143101.0],
#   [1995, 34942188.0],
#   [2004, 143597.0],
#   [2006, 101624843.0],
#   [2008, 414404.0],
#   [2009, 7002261.0]],
#  'Sean Penn': [[1991, 191125.0], [2007, 56255142.0], [2010, 29400000.0]],
#  'Kevin Smith': [[1982, 0.0],
#   [1994, 3151130.0],
#   [2003, 33788161.0],
#   [2006, 26888376.0],
#   [2006, 36098382.0],
#   [2010, 55583804.0],
#   [2011, 0.0],
#   [2011, 1104682.0],
#   [2012, 0.0],
#   [2013, 0.0],
#   [2015, 0.0]],
#  'Geoffrey Sax': [[1991, 0.0],
#   [1996, 42000000.0],
#   [2005, 91196419.0],
#   [2006, 23937870.0]],
#  'Scott Hicks': [[2001, 0.0], [2003, 0.0], [2003, 0.0], [2007, 20.0]],
#  'David Bowers': [[2009, 19551067.0],
#   [2011, 72417394.0],
#   [2012, 77112176.0],
#   [2016, 178120010.0],
#   [2017, 40120144.0]],
#  'Adam McKay': [[1975, 0.0],
#   [2006, 162966177.0],
#   [2008, 128107642.0],
#   [2011, 0.0],
#   [2014, 173649015.0],
#   [2015, 133346506.0]],
#  'Dwight H. Little': [[1988, 17768757.0],
#   [1988, 0.0],
#   [1990, 46044400.0],
#   [1992, 0.0],
#   [2003, 0.0],
#   [2004, 0.0]],
#  'Tom Dey': [[2002, 0.0], [2010, 83761844.0], [2011, 0.0], [2015, 0.0]],
#  'Nora Ephron': [[1978, 131426169.0],
#   [1992, 119718203.0],
#   [1993, 227799884.0],
#   [1998, 250821495.0],
#   [2009, 129540499.0]],
#  'Alex Gibney': [[1997, 0.0],
#   [2002, 274661.0],
#   [2013, 602042.0],
#   [2015, 494506.0]],
#  'Kodi Rama Krishna': [[2009, 14000000.0]],
#  'Andrew Neel': [[2016, 23020.0]],
#  'Michael Mann': [[1978, 8620929.0],
#   [1981, 4300000.0],
#   [1982, 187436818.0],
#   [1983, 3661757.0],
#   [1992, 75505856.0],
#   [1999, 60289912.0],
#   [2004, 217764291.0],
#   [2006, 163794509.0],
#   [2009, 214104620.0],
#   [2010, 87713825.0],
#   [2016, 17752940.0]],
#  'Louis Morneau': [[1999, 10.0]],
#  'Drew Goddard': [[2012, 66486080.0]],
#  'Richard LaGravenese': [[1998, 12902790.0],
#   [2004, 156835339.0],
#   [2006, 60052138.0],
#   [2007, 41170784.0],
#   [2009, 0.0]],
#  'C√©dric Klapisch': [[2002, 3897799.0],
#   [2005, 23727301.0],
#   [2008, 23550000.0]],
#  'David Ayer': [[1937, 745600054.0],
#   [2002, 211817906.0],
#   [2005, 5967038.0],
#   [2011, 0.0],
#   [2012, 48126384.0],
#   [2014, 17508518.0]],
#  'Stuart Gordon': [[1986, 1261000.0],
#   [1992, 2023414.0],
#   [1996, 1614266.0],
#   [2013, 6739141.0]],
#  'M. Night Shyamalan': [[1994, 672806292.0],
#   [2002, 408247917.0],
#   [2008, 163403799.0],
#   [2012, 248118121.0],
#   [2012, 0.0],
#   [2012, 256697520.0],
#   [2013, 243843127.0],
#   [2015, 98450062.0],
#   [2016, 276921998.0],
#   [2016, 42285169.0]],
#  'Reggie Rock Bythewood': [[2003, 23510601.0]],
#  'Don Bluth': [[1946, 3983912.0],
#   [1991, 11657385.0],
#   [1992, 84460846.0],
#   [1994, 11373501.0],
#   [1997, 84542002.0],
#   [1999, 0.0]],
#  'Mike Newell': [[1982, 0.0],
#   [1994, 254700832.0],
#   [1997, 41954997.0],
#   [1997, 258656.0],
#   [2001, 0.0],
#   [2007, 851545.0],
#   [2010, 895921036.0],
#   [2023, 335154643.0]],
#  'Scott Frank': [[2007, 5367030.0], [2028, 53181600.0]],
#  'Angelina Jolie': [[1998, 303877.0], [2000, 3727746.0], [2014, 163442937.0]],
#  'Bruno Barreto': [[1997, 310724.0], [2007, 15614000.0]],
#  'Francis Lawrence': [[1985, 0.0],
#   [2000, 0.0],
#   [2005, 230884728.0],
#   [2007, 585349010.0],
#   [2014, 0.0],
#   [2015, 653428261.0]],
#  'Fyodor Bondarchuk': [[2000, 24000000.0],
#   [2001, 21834845.0],
#   [2009, 5873871.0],
#   [2013, 68129518.0]],
#  'Tom Shadyac': [[1975, 484572835.0],
#   [1994, 107217396.0],
#   [1997, 302710615.0],
#   [2002, 52322400.0],
#   [2007, 173000000.0],
#   [2008, 128769345.0],
#   [2008, 0.0]],
#  'Paul Mazursky': [[1969, 30000000.0],
#   [1991, 9563393.0],
#   [1996, 9789900.0],
#   [2002, 24000000.0],
#   [2010, 62134225.0],
#   [2013, 7754571.0],
#   [2015, 25100000.0]],
#  'Ate de Jong': [[1991, 26055.0], [1991, 13878334.0]],
#  'Ron Underwood': [[1990, 48572000.0],
#   [1991, 179033791.0],
#   [1993, 16589540.0],
#   [2002, 7103973.0]],
#  'Wesley Ruggles': [[1933, 2850000.0]],
#  'John Turturro': [[2005, 2945242.0], [2013, 2681345.0]],
#  'Sidney Lumet': [[1957, 1000000.0],
#   [1974, 27634716.0],
#   [1975, 23689877.0],
#   [1978, 21049053.0],
#   [1986, 25147055.0],
#   [1988, 2835116.0],
#   [1993, 22886222.0],
#   [1996, 0.0],
#   [1999, 46665856.0],
#   [2000, 29800000.0],
#   [2006, 2636637.0],
#   [2007, 25005257.0],
#   [2015, 53977250.0]],
#  'Aaron Norris': [[1988, 6193901.0],
#   [1990, 6698361.0],
#   [1999, 4654288.0],
#   [2010, 5093707.0]],
#  'Martin Scorsese': [[1973, 3000000.0],
#   [1976, 28262574.0],
#   [1976, 185770160.0],
#   [1980, 23000000.0],
#   [1985, 10609321.0],
#   [1986, 52293982.0],
#   [1988, 8373585.0],
#   [1991, 0.0],
#   [1993, 0.0],
#   [1996, 0.0],
#   [1997, 5684789.0],
#   [2002, 193772504.0],
#   [2002, 289847354.0],
#   [2004, 102000000.0],
#   [2004, 0.0],
#   [2008, 46836394.0],
#   [2016, 116112375.0],
#   [2017, 294804195.0]],
#  'Spike Jonze': [[1987, 32801173.0],
#   [2009, 100086793.0],
#   [2014, 0.0],
#   [2015, 0.0]],
#  'Ben Affleck': [[2008, 34619699.0],
#   [2010, 154026136.0],
#   [2012, 232324128.0],
#   [2016, 22678555.0]],
#  'Mark Waters': [[1975, 0.0],
#   [1980, 0.0],
#   [2003, 110230332.0],
#   [2003, 626057.0],
#   [2004, 129042871.0],
#   [2009, 102223269.0],
#   [2009, 0.0],
#   [2011, 187361754.0],
#   [2015, 10424470.0]],
#  'Atom Egoyan': [[1980, 0.0],
#   [2009, 8459458.0],
#   [2014, 3263585.0],
#   [2015, 1986615.0]],
#  'Xavier Dolan': [[2010, 62985.0], [2012, 12250.0], [2013, 3494070.0]],
#  'Lance Rivera': [[1977, 5800000.0], [2004, 12.0]],
#  'R.D. Robb': [[2001, 6297.0]],
#  'Brian Fee': [[2017, 350170057.0]],
#  'Clint Eastwood': [[1975, 14200000.0],
#   [1977, 26414658.0],
#   [1983, 67642693.0],
#   [1985, 41410568.0],
#   [1986, 42724017.0],
#   [1987, 68673228.0],
#   [1993, 135130999.0],
#   [1993, 269958228.0],
#   [1993, 0.0],
#   [1995, 128884132.0],
#   [1997, 50068310.0],
#   [1999, 105197635.0],
#   [2000, 122233971.0],
#   [2002, 26199517.0],
#   [2002, 159157447.0],
#   [2002, 542307423.0],
#   [2003, 156822020.0],
#   [2004, 0.0],
#   [2005, 65900249.0],
#   [2007, 182016617.0],
#   [2008, 113020255.0],
#   [2011, 21633874.0],
#   [2011, 25105255.0],
#   [2013, 0.0],
#   [2014, 67347013.0],
#   [2014, 0.0],
#   [2014, 0.0],
#   [2016, 238470033.0],
#   [2016, 15700000.0]],
#  'Jeff Newitt': [[2012, 118338361.0]],
#  'Neill Blomkamp': [[2009, 210819611.0],
#   [2013, 286140700.0],
#   [2015, 104399548.0]],
#  'Shusuke Kaneko': [[1992, 50710400.0], [2006, 27793200.0]],
#  'Peter Weir': [[1977, 1258000.0],
#   [1982, 1317657.0],
#   [1985, 68706993.0],
#   [1988, 212011111.0],
#   [1989, 235860116.0],
#   [1990, 0.0],
#   [1998, 264118201.0],
#   [2004, 20348249.0],
#   [2012, 0.0],
#   [2016, 14302779.0]],
#  'David Drury': [[1986, 750000.0]],
#  'Tarsem Singh': [[1987, 226904017.0],
#   [2008, 3669465.0],
#   [2011, 30523226.0],
#   [2012, 183018522.0],
#   [2015, 104155843.0]],
#  'Alejandro Gonz√°lez I√±√°rritu': [[1989, 0.0],
#   [2000, 20908467.0],
#   [2003, 60427839.0],
#   [2009, 103215094.0],
#   [2010, 25147786.0],
#   [2015, 532950503.0]],
#  'Brian Helgeland': [[1999, 161626121.0],
#   [2001, 117487473.0],
#   [2003, 11560806.0],
#   [2009, 95020213.0],
#   [2016, 42972994.0]],
#  'Betty Thomas': [[1967, 41009669.0],
#   [1981, 443140005.0],
#   [1998, 294456605.0],
#   [2007, 0.0],
#   [2014, 33561137.0]],
#  'Hugh Wilson': [[1969, 293793.0],
#   [1996, 116400000.0],
#   [1999, 40263020.0],
#   [2017, 146198896.0]],
#  'Olivier Megaton': [[1981, 0.0],
#   [1997, 0.0],
#   [2009, 376141306.0],
#   [2011, 60965854.0]],
#  'Shana Feste': [[2010, 20529194.0], [2014, 34077920.0]],
#  'Stuart Gillard': [[1982, 5588800.0], [2014, 0.0]],
#  'Teddy Chan': [[1970, 3849941.0], [2009, 5837674.0], [2014, 129115.0]],
#  'Bernie Goldmann': [[2007, 346592.0]],
#  'Henry King': [[1938, 4000000.0], [1949, 3225000.0], [2009, 2000000.0]],
#  'Hari': [[2003, 3.0], [2010, 9700000.0]],
#  'Tar√¥ Ohtani': [[2010, 9833553.0]],
#  'Danny Cannon': [[1995, 113493481.0], [1998, 40002112.0], [2005, 27610873.0]],
#  'Martin Ritt': [[1954, 22228000.0],
#   [1970, 2200000.0],
#   [1990, 5820015.0],
#   [1990, 10000000.0],
#   [2006, 12000000.0],
#   [2010, 0.0]],
#  'Guy Jenkin': [[2014, 1289998.0]],
#  'Gary Fleder': [[1991, 43058898.0],
#   [1995, 529766.0],
#   [1997, 60527873.0],
#   [2001, 100020092.0],
#   [2003, 80154140.0],
#   [2014, 0.0]],
#  'George Bamber': [[2005, 152810.0]],
#  'Tim Burstall': [[1982, 88000.0]],
#  'Kenneth Branagh': [[1956, 112006296.0],
#   [1991, 0.0],
#   [2002, 0.0],
#   [2009, 0.0],
#   [2013, 0.0],
#   [2014, 50549107.0],
#   [2015, 0.0]],
#  'Bud Yorkin': [[1988, 14681192.0]],
#  'David Frankel': [[1991, 0.0],
#   [1993, 0.0],
#   [1995, 5.0],
#   [1997, 10900434.0],
#   [2000, 0.0],
#   [2014, 0.0],
#   [2016, 87416021.0]],
#  'Terry Jones': [[1979, 20045115.0], [1987, 0.0], [1996, 1.0], [2015, 0.0]],
#  'Hayao Miyazaki': [[1984, 3301446.0],
#   [1985, 202404009.0],
#   [1987, 274925095.0],
#   [1990, 117932401.0],
#   [1991, 236049757.0],
#   [2008, 159375308.0],
#   [2012, 18172849.0]],
#  'Ross Kauffman': [[2004, 3515061.0]],
#  'Peter Berg': [[1980, 80916492.0],
#   [1998, 0.0],
#   [2004, 0.0],
#   [2007, 86658558.0],
#   [2008, 0.0],
#   [2013, 149295601.0],
#   [2015, 303025485.0],
#   [2016, 121790373.0],
#   [2016, 50548152.0]],
#  'Guy Hamilton': [[1963, 7230000.0],
#   [1971, 116019547.0],
#   [1980, 11000000.0],
#   [1985, 14393902.0],
#   [1995, 6110000.0],
#   [2002, 0.0],
#   [2010, 0.0],
#   [2014, 0.0]],
#  'Art Linson': [[1980, 6659377.0], [1984, 9500000.0]],
#  'DJ Pooh': [[2000, 9000000.0], [2001, 10229331.0]],
#  'Lexi Alexander': [[2003, 3154346.0], [2008, 10089373.0]],
#  'John Scheinfeld': [[2010, 28200.0], [2017, 393970.0]],
#  'Rob Minkoff': [[1984, 0.0],
#   [1994, 788241776.0],
#   [2003, 182290266.0],
#   [2004, 0.0],
#   [2006, 3142154.0],
#   [2012, 169956806.0],
#   [2014, 300135367.0]],
#  'Paul W.S. Anderson': [[1996, 122195920.0],
#   [1998, 14567883.0],
#   [2002, 102984862.0],
#   [2004, 171183863.0],
#   [2004, 0.0],
#   [2008, 73762516.0],
#   [2010, 300228084.0],
#   [2011, 132274484.0],
#   [2012, 240159255.0],
#   [2014, 117831631.0],
#   [2016, 312242626.0]],
#  'Otto Bell': [[2016, 3162153.0]],
#  'Renat Davletyarov': [[2015, 5249225.0]],
#  'Jacques Audiard': [[2012, 25762027.0], [2015, 248392.0]],
#  'Shane Carruth': [[2004, 424760.0], [2013, 444098.0]],
#  'Randall Wallace': [[2002, 114660784.0], [2011, 0.0], [2014, 101332962.0]],
#  'Claude Zidi': [[1999, 1644060.0]],
#  'Rebecca Miller': [[2005, 712294.0], [2016, 3351735.0]],
#  'David Gelb': [[2013, 2550508.0], [2015, 64110728.0]],
#  'Mike Leigh': [[1988, 1192322.0],
#   [1991, 0.0],
#   [2001, 18130888.0],
#   [2008, 5405500.0],
#   [2010, 18124262.0]],
#  'Anees Bazmee': [[1987, 25000000.0], [2011, 4100000.0], [2016, 36500000.0]],
#  'John Moore': [[1994, 21009180.0],
#   [2001, 91753202.0],
#   [2003, 0.0],
#   [2006, 0.0],
#   [2008, 85416905.0]],
#  "John 'Bud' Cardos": [[1977, 17000000.0]],
#  'Igor Kovalyov': [[1998, 100491683.0]],
#  'Joel Coen': [[1961, 0.0],
#   [1990, 5080409.0],
#   [1995, 163720069.0],
#   [1996, 60611975.0],
#   [1996, 0.0],
#   [1997, 63647656.0],
#   [2003, 119940815.0],
#   [2007, 171627166.0],
#   [2010, 252276927.0],
#   [2012, 0.0],
#   [2015, 71868327.0]],
#  'Gary Chapman': [[2005, 19478106.0]],
#  'Robert Budreau': [[2015, 830129.0]],
#  'Edward Zwick': [[1980, 0.0],
#   [1986, 51155219.0],
#   [1989, 26828365.0],
#   [1994, 160638883.0],
#   [1998, 116672912.0],
#   [2004, 38702310.0],
#   [2005, 100860818.0],
#   [2006, 170877916.0],
#   [2006, 0.0],
#   [2010, 102820008.0],
#   [2010, 162146076.0]],
#  'Jean-Jacques Annaud': [[2001, 96976270.0],
#   [2001, 77200000.0],
#   [2001, 131457682.0],
#   [2004, 62172050.0],
#   [2006, 123205624.0],
#   [2011, 5446000.0],
#   [2013, 55260558.0],
#   [2015, 138241022.0]],
#  'John Dahl': [[1993, 2000000.0],
#   [1996, 2426851.0],
#   [1998, 22921898.0],
#   [2001, 36642838.0],
#   [2005, 10166502.0]],
#  'Joe Wright': [[1986, 129266061.0],
#   [1996, 63782078.0],
#   [2009, 31720158.0],
#   [2012, 68929150.0],
#   [2015, 128388320.0],
#   [2015, 121147947.0]],
#  'Oliver Stone': [[1957, 82966152.0],
#   [1975, 162945894.0],
#   [1981, 566736.0],
#   [1987, 43848069.0],
#   [1988, 0.0],
#   [1989, 0.0],
#   [1994, 0.0],
#   [1997, 6682098.0],
#   [1999, 100230832.0],
#   [2006, 0.0],
#   [2007, 29506464.0],
#   [2009, 0.0],
#   [2010, 134748021.0],
#   [2010, 0.0],
#   [2011, 34416893.0],
#   [2013, 205405498.0],
#   [2016, 37279439.0]],
#  'Steve Bendelack': [[2007, 229736344.0]],
#  'Ryan Piers Williams': [[2010, 12000.0]],
#  'Hector Babenco': [[1991, 1345903.0]],
#  'Mike Gunther': [[2011, 2128186.0]],
#  'Peter Segal': [[1994, 51132598.0],
#   [1995, 32648673.0],
#   [2003, 195745823.0],
#   [2004, 196482882.0],
#   [2004, 123307945.0],
#   [2005, 190320568.0],
#   [2008, 230685453.0],
#   [2016, 0.0]],
#  'Alessandro Genovesi': [[2011, 12935800.0], [2012, 10703234.0]],
#  'Dmitriy Kiselev': [[1985, 0.0], [2017, 9868942.0]],
#  'Fr√©d√©ric Mermoud': [[2016, 126463.0]],
#  'Hal Needham': [[1977, 126737428.0],
#   [1980, 66132626.0],
#   [1981, 72179579.0],
#   [1983, 0.0],
#   [2006, 78000000.0],
#   [2012, 2015882.0]],
#  'Sean McGinly': [[2008, 900689.0]],
#  'Leslie Small': [[2013, 32230907.0]],
#  'Philippe Mora': [[1989, 1919653.0]],
#  'Gary David Goldberg': [[1989, 19738015.0], [2005, 58405313.0]],
#  'Rajkumar Santoshi': [[2000, 0.0], [2002, 6000000.0]],
#  'Shawn Christensen': [[2014, 8251.0]],
#  'Jesse V. Johnson': [[2013, 1469.0]],
#  'Sean S. Cunningham': [[1980, 59754601.0], [1989, 8143225.0]],
#  'Jim Gillespie': [[1997, 125586134.0], [2003, 6416302.0]],
#  'Ralph Bakshi': [[1973, 1500000.0],
#   [1978, 30471420.0],
#   [1981, 6000000.0],
#   [1983, 760883.0],
#   [1986, 9000000.0],
#   [1992, 14110589.0]],
#  'Stephen Herek': [[1989, 40485039.0],
#   [1991, 25196249.0],
#   [1993, 53898845.0],
#   [1995, 106269971.0],
#   [2001, 16991902.0],
#   [2002, 0.0],
#   [2005, 13167232.0],
#   [2006, 50752337.0],
#   [2016, 320689294.0]],
#  'Michael Caton-Jones': [[1989, 8800000.0],
#   [1993, 4104962.0],
#   [1996, 22433915.0],
#   [1997, 159330280.0],
#   [2006, 31596911.0],
#   [2011, 38629478.0]],
#  'James Cameron': [[1956, 0.0],
#   [1983, 0.0],
#   [1984, 78371200.0],
#   [1986, 183316455.0],
#   [1990, 0.0],
#   [1997, 1845034188.0],
#   [2006, 17040871.0],
#   [2015, 90000098.0]],
#  'Gary Ross': [[2003, 148336445.0], [2010, 691210692.0], [2016, 25035950.0]],
#  'Lasse Hallstr√∂m': [[1973, 37691644.0],
#   [1984, 114977104.0],
#   [1993, 10032765.0],
#   [1994, 47801389.0],
#   [1995, 50892160.0],
#   [1998, 11772461.0],
#   [1999, 88545092.0],
#   [2000, 152500343.0],
#   [2002, 18618284.0],
#   [2005, 88880821.0],
#   [2011, 34564651.0],
#   [2013, 97594140.0],
#   [2017, 194647323.0]],
#  'Martin Koolhoven': [[2006, 966214.0], [2008, 530048.0]],
#  'Larry Charles': [[2006, 0.0], [2012, 179379533.0]],
#  'Simon West': [[1979, 0.0],
#   [1989, 224012234.0],
#   [1990, 0.0],
#   [1999, 149705852.0],
#   [2006, 66966987.0],
#   [2011, 51070807.0],
#   [2012, 2106557.0]],
#  'Yojiro Takita': [[2008, 69932387.0]],
#  'Ruggero Deodato': [[1985, 373530.0]],
#  'Catherine Hardwicke': [[2003, 4601043.0],
#   [2008, 393616788.0],
#   [2011, 89162162.0],
#   [2015, 13411957.0]],
#  'Ashwani Dhir': [[2010, 5000000.0]],
#  'Woody Allen': [[1968, 0.0],
#   [1979, 39946780.0],
#   [1983, 11798616.0],
#   [1986, 40084041.0],
#   [1987, 0.0],
#   [1988, 35097815.0],
#   [1992, 0.0],
#   [1993, 11285588.0],
#   [1994, 18344729.0],
#   [1995, 6700000.0],
#   [1997, 2735731.0],
#   [2002, 0.0],
#   [2003, 99206215.0],
#   [2004, 20085825.0],
#   [2005, 85306374.0],
#   [2006, 31584901.0],
#   [2008, 0.0],
#   [2009, 11833696.0],
#   [2011, 151119219.0],
#   [2011, 0.0],
#   [2011, 38251425.0],
#   [2012, 73244881.0],
#   [2012, 20173742.0],
#   [2014, 51029361.0],
#   [2014, 0.0],
#   [2015, 18016290.0],
#   [2015, 0.0]],
#  'Brian Gibson': [[1986, 40996665.0]],
#  'Scott Sanders': [[2009, 296557.0]],
#  'James McTeigue': [[2006, 132511035.0], [2012, 29657751.0], [2012, 0.0]],
#  'Anthony Byrne': [[2007, 706000.0]],
#  'Leos Carax': [[2012, 641100.0]],
#  'Fred Savage': [[2007, 18197398.0]],
#  'Borja Cobeaga': [[2009, 2012927.0]],
#  'Christopher Nolan': [[1979, 0.0],
#   [1998, 48482.0],
#   [2005, 374218673.0],
#   [2006, 109676311.0],
#   [2008, 1004558444.0],
#   [2010, 825532764.0],
#   [2014, 0.0],
#   [2015, 0.0]],
#  'Richard Linklater': [[1974, 0.0],
#   [1981, 5535405.0],
#   [1993, 7993039.0],
#   [1996, 656747.0],
#   [2002, 0.0],
#   [2004, 15992615.0],
#   [2005, 34252847.0],
#   [2006, 7659918.0],
#   [2009, 2336172.0],
#   [2009, 131282949.0],
#   [2012, 490475.0],
#   [2013, 11176469.0],
#   [2014, 44349000.0],
#   [2015, 0.0],
#   [2016, 3400278.0]],
#  'Eric Bress': [[2004, 96060858.0]],
#  'Kathryn Bigelow': [[1984, 0.0],
#   [1999, 83531958.0],
#   [2000, 109130.0],
#   [2003, 7959291.0],
#   [2008, 0.0],
#   [2012, 132820716.0]],
#  'Gore Verbinski': [[1990, 1065659812.0],
#   [1997, 122417389.0],
#   [1998, 0.0],
#   [2001, 147845033.0],
#   [2003, 655011224.0],
#   [2003, 249348933.0],
#   [2007, 961000000.0],
#   [2010, 26559557.0],
#   [2011, 245724603.0],
#   [2015, 0.0]],
#  'Michael Polish': [[1992, 4842699.0],
#   [2001, 43719.0],
#   [2004, 0.0],
#   [2006, 11130889.0]],
#  'Jeff Bleckner': [[1987, 300859.0]],
#  'A.J. Edwards': [[2014, 70918.0]],
#  'Peter Howitt': [[1988, 30016165.0],
#   [2001, 18195610.0],
#   [2003, 160583018.0],
#   [2003, 58000000.0]],
#  'Kleber Mendon√ßa Filho': [[2016, 285930.0]],
#  'Noam Murro': [[2014, 337580051.0], [2015, 10569964.0]],
#  'Errol Morris': [[1993, 0.0], [1997, 832735.0]],
#  'Phillip Borsos': [[1985, 4300000.0]],
#  'Nicole Garcia': [[2016, 47748.0]],
#  'Bill Fishman': [[1988, 343786.0], [1994, 1238080.0]],
#  'John Hyams': [[2000, 1402307.0], [2009, 875386.0]],
#  'Chris Noonan': [[1995, 254134910.0], [2006, 35078241.0]],
#  'Andy Cadiff': [[2004, 12.0]],
#  'Gee Malik Linton': [[2016, 1787926.0]],
#  'Richard Ramsey': [[2014, 1009620.0]],
#  'Anthony Hickox': [[1992, 12534961.0], [2016, 0.0]],
#  'Robert Greenwald': [[1980, 22471595.0], [1988, 3790493.0], [1994, 11690.0]],
#  'Paddy Breathnach': [[2001, 637769.0], [2007, 4910682.0]],
#  'Alfred Hitchcock': [[1940, 6000000.0],
#   [1948, 2200000.0],
#   [1954, 36764313.0],
#   [1955, 8750000.0],
#   [1955, 7000000.0],
#   [1959, 13275000.0],
#   [1960, 32000000.0],
#   [1963, 11403529.0],
#   [1969, 6000000.0],
#   [1972, 12600000.0],
#   [1976, 7900000.0],
#   [1990, 28000000.0],
#   [1993, 13000000.0],
#   [1995, 3000000.0],
#   [1996, 0.0],
#   [1997, 0.0],
#   [2000, 4500000.0],
#   [2007, 7000000.0],
#   [2012, 2000000.0],
#   [2013, 0.0],
#   [2016, 0.0]],
#  'Tom Kalin': [[1992, 340147.0]],
#  'Robert Rodriguez': [[1988, 85564310.0],
#   [1992, 2040920.0],
#   [1995, 25405445.0],
#   [1995, 40283321.0],
#   [1996, 25836616.0],
#   [1997, 119723358.0],
#   [2001, 147934180.0],
#   [2003, 98185582.0],
#   [2003, 197011982.0],
#   [2007, 28972508.0],
#   [2009, 69425966.0],
#   [2010, 31327899.0],
#   [2013, 15008161.0],
#   [2014, 39407616.0]],
#  'Fons Rademakers': [[1986, 203781.0]],
#  'Andy Fickman': [[1999, 32005248.0],
#   [2006, 33889159.0],
#   [2007, 147880543.0],
#   [2009, 106303988.0],
#   [2012, 119772232.0],
#   [2015, 107597242.0]],
#  'Robert Zemeckis': [[1980, 11715321.0],
#   [1988, 329803958.0],
#   [1989, 332000000.0],
#   [1990, 244527583.0],
#   [1993, 149022650.0],
#   [1994, 429632142.0],
#   [1996, 677945399.0],
#   [1997, 171120329.0],
#   [2001, 195735876.0],
#   [2004, 305875730.0],
#   [2005, 325233863.0],
#   [2006, 0.0],
#   [2008, 0.0],
#   [2012, 161772375.0],
#   [2015, 381109762.0],
#   [2017, 86572238.0],
#   [2017, 291420351.0]],
#  'Patrick Read Johnson': [[1990, 15369573.0], [1994, 16671505.0]],
#  'Peter Yates': [[1979, 20000000.0],
#   [1983, 16519460.0],
#   [1987, 18782400.0],
#   [1990, 0.0],
#   [2000, 42300873.0],
#   [2011, 0.0]],
#  'Sylvester Stallone': [[1978, 7185518.0],
#   [1979, 200182160.0],
#   [1982, 270000000.0],
#   [2008, 113244290.0],
#   [2010, 274470394.0],
#   [2011, 300473716.0],
#   [2013, 0.0],
#   [2017, 155721132.0]],
#  'Joe Nussbaum': [[2007, 13620075.0], [2011, 10130000.0]],
#  'Anne Fontaine': [[2012, 154701.0], [2013, 318982.0]],
#  'Joseph Ruben': [[1972, 12145169.0],
#   [1976, 0.0],
#   [1991, 174999005.0],
#   [1993, 44456478.0],
#   [1995, 35431113.0],
#   [2010, 117575636.0],
#   [2017, 240978.0]],
#  'Stefan Ruzowitzky': [[2001, 23000.0], [2012, 66351.0]],
#  'Svyatoslav Ushakov': [[2010, 6500000.0]],
#  'Ram√≥n Ob√≥n': [[2012, 1612100.0]],
#  'Howard Deutch': [[1987, 18553948.0],
#   [1988, 43455230.0],
#   [1992, 6375979.0],
#   [2004, 26155781.0],
#   [2005, 40471663.0],
#   [2008, 0.0]],
#  'Lorene Scafaria': [[1997, 0.0], [2016, 4267218.0]],
#  'John Bonito': [[2006, 22165608.0]],
#  'George Marshall': [[1954, 1300000.0]],
#  'Nikhil Advani': [[2003, 13200241.0], [2009, 9400000.0]],
#  'Penny Marshall': [[1990, 52096475.0],
#   [1994, 24332324.0],
#   [1996, 48093211.0],
#   [2001, 35743308.0],
#   [2006, 132440069.0],
#   [2025, 151927281.0]],
#  'Roland Emmerich': [[1986, 379014294.0],
#   [2005, 0.0],
#   [2008, 266000000.0],
#   [2008, 0.0],
#   [2009, 817400891.0],
#   [2011, 15395087.0],
#   [2013, 205366737.0],
#   [2014, 0.0],
#   [2015, 187674.0],
#   [2015, 0.0]],
#  'Bob Balaban': [[1993, 3335984.0]],
#  'Robert Redford': [[1991, 19633027.0],
#   [1992, 0.0],
#   [1998, 186883563.0],
#   [2000, 39459427.0],
#   [2007, 63215872.0],
#   [2010, 15478800.0]],
#  'Ilya Maksimov': [[2006, 3468423.0]],
#  'James DeMonaco': [[2009, 118587880.0], [2013, 0.0], [2014, 108782847.0]],
#  'Todd Haynes': [[1991, 609524.0],
#   [1998, 1053788.0],
#   [2004, 29027914.0],
#   [2007, 4001121.0],
#   [2015, 40272135.0]],
#  'Adam Elliot': [[2009, 1725381.0]],
#  'Anders Anderson': [[2009, 7306.0]],
#  'David Hogan': [[1997, 11838218.0], [2000, 0.0]],
#  'Justin Barber': [[2017, 3600000.0]],
#  'Kevin Hooks': [[1981, 0.0], [1992, 44065653.0], [2009, 0.0]],
#  'Tony Kaye': [[1998, 23875127.0], [2006, 25.0], [2007, 72689.0]],
#  'Genndy Tartakovsky': [[1993, 358375603.0], [2015, 473226958.0]],
#  'Jean-Pierre Melville': [[1967, 39481.0], [1969, 741766.0]],
#  'Cameron Crowe': [[1974, 203388341.0],
#   [1991, 47383689.0],
#   [1992, 0.0],
#   [1996, 0.0],
#   [1999, 20036737.0],
#   [2005, 52034889.0],
#   [2011, 120081841.0],
#   [2015, 26250020.0]],
#  'Andrew Niccol': [[1988, 0.0],
#   [1997, 0.0],
#   [2013, 63327201.0],
#   [2014, 19576023.0],
#   [2015, 316472.0],
#   [2015, 72617068.0]],
#  'John Sturges': [[1955, 3788000.0],
#   [1957, 11750000.0],
#   [1960, 4905000.0],
#   [2012, 6330000.0],
#   [2016, 11744471.0]],
#  'St√©phane Rybojad': [[2011, 10759.0]],
#  'Stuart Baird': [[1963, 67312826.0], [1998, 102367405.0], [2015, 0.0]],
#  'Darren Aronofsky': [[1998, 3221152.0],
#   [1998, 15304890.0],
#   [2000, 7390108.0],
#   [2008, 44703995.0],
#   [2010, 327803731.0],
#   [2014, 362637473.0]],
#  'Gr√©gory Levasseur': [[2014, 13865435.0]],
#  'Elia Kazan': [[1947, 7800000.0],
#   [1954, 9600000.0],
#   [1955, 5.0],
#   [2009, 8000000.0]],
#  'Angel Gracia': [[2011, 2500000.0]],
#  'Michael Damian': [[1997, 37895.0], [2016, 53447.0]],
#  'David Koepp': [[1999, 21133087.0],
#   [2005, 0.0],
#   [2010, 0.0],
#   [2015, 92913171.0]],
#  'Mani Ratnam': [[1971, 0.0],
#   [1998, 13000000.0],
#   [1999, 31000000.0],
#   [2000, 6000000.0],
#   [2015, 5100000.0]],
#  'James Marsh': [[2002, 0.0], [2012, 419953.0], [2014, 123726688.0]],
#  'Paul Thomas Anderson': [[1988, 77208711.0],
#   [1999, 48451803.0],
#   [1999, 0.0],
#   [2002, 17000000.0],
#   [2003, 0.0],
#   [2003, 43101594.0],
#   [2012, 28258060.0]],
#  'James Keach': [[2006, 834457.0], [2014, 365522.0]],
#  'Tim Burton': [[1980, 362211740.0],
#   [1985, 40940662.0],
#   [1986, 122919055.0],
#   [1988, 73326666.0],
#   [1989, 411348924.0],
#   [1989, 101371017.0],
#   [1990, 53000000.0],
#   [1992, 280000000.0],
#   [1994, 5887457.0],
#   [2004, 296485719.0],
#   [2005, 117195061.0],
#   [2007, 152000000.0],
#   [2010, 1025491110.0],
#   [2012, 35287788.0],
#   [2013, 474968763.0],
#   [2014, 28883511.0],
# ...
#  'Clive Donner': [[1967, 1000000.0]],
#  'Luca Guadagnino': [[2005, 5151936.0], [2015, 1982505.0]],
#  'Crystal Moselle': [[2015, 1301696.0]],
#  'Dario Argento': [[2004, 1479042.0], [2009, 0.0]],
#  'Glenn Ficarra': [[2001, 153962963.0],
#   [2008, 20722843.0],
#   [2011, 142851197.0]],
#  'Bora Daƒütekin': [[2015, 83027924.0]],
#  'David Yates': [[1984, 1342000000.0],
#   [2007, 356743061.0],
#   [2009, 933959197.0],
#   [2015, 0.0],
#   [2016, 954305868.0]],
#  'Dominik Moll': [[2000, 0.0], [2011, 807535.0], [2011, 3818452.0]],
#  'Gillo Pontecorvo': [[1966, 921548.0]],
#  'Stephen Kessler': [[1997, 36400360.0]],
#  'Thomas Vinterberg': [[1990, 18309793.0], [2015, 30229977.0]],
#  'P.J. Hogan': [[1984, 299288605.0],
#   [1994, 15119639.0],
#   [1995, 0.0],
#   [2009, 108332743.0]],
#  'Sabbir Khan': [[2014, 10000000.0]],
#  'James Wan': [[2004, 103911669.0],
#   [2007, 16974459.0],
#   [2007, 0.0],
#   [2009, 0.0],
#   [2013, 318000141.0],
#   [2015, 1506249360.0],
#   [2016, 320170008.0]],
#  'Alan J. Pakula': [[1976, 70600000.0],
#   [1996, 10217873.0],
#   [1998, 0.0],
#   [2000, 21591728.0],
#   [2003, 221303188.0],
#   [2009, 0.0],
#   [2011, 30036000.0]],
#  'R.J. Cutler': [[2014, 78874843.0]],
#  'Anthony Bell': [[2010, 39300000.0]],
#  'Luc Besson': [[1975, 3759582.0],
#   [1985, 390659.0],
#   [1990, 5000000.0],
#   [1993, 45284974.0],
#   [1997, 263920180.0],
#   [1999, 66976317.0],
#   [2001, 126546825.0],
#   [2009, 107944236.0],
#   [2010, 34100000.0],
#   [2013, 36894225.0]],
#  'Rick Rosenthal': [[1981, 0.0],
#   [1983, 9190819.0],
#   [1987, 2189047.0],
#   [2002, 37664855.0]],
#  'Jan de Bont': [[1996, 494471524.0],
#   [1997, 164508066.0],
#   [1999, 91188905.0],
#   [2010, 350448145.0],
#   [2018, 156505388.0]],
#  'Greg Berlanti': [[2000, 1744858.0], [2010, 105610124.0]],
#  'Daniel Calparsoro': [[2016, 12118661.0]],
#  'Yoav Potash': [[2011, 58840.0]],
#  'Sacha Gervasi': [[2012, 23570541.0]],
#  'Richard Benjamin': [[1959, 54999651.0],
#   [1965, 0.0],
#   [1984, 6045657.0],
#   [1986, 18137661.0],
#   [1990, 2346150.0],
#   [1990, 0.0],
#   [1999, 0.0],
#   [2003, 1675706.0],
#   [2014, 10070000.0]],
#  'Zeresenay Mehari': [[2014, 49667.0]],
#  'Mark Sandrich': [[1935, 3202000.0]],
#  'Kazuaki Kiriya': [[1986, 3643591.0], [2004, 1530216.0], [2007, 16000000.0]],
#  'Shinji Higuchi': [[2005, 47636016.0], [2016, 77000000.0]],
#  'Fran√ßois Truffaut': [[1968, 44566.0], [1972, 457163.0], [1973, 17808.0]],
#  'Kristian Levring': [[2014, 42070000.0]],
#  'Shainee Gabel': [[2004, 1841260.0]],
#  'Ritesh Batra': [[2013, 4235151.0]],
#  'John Penney': [[2006, 30.0]],
#  'Manny Rodriguez': [[2011, 60.0]],
#  'Tom McLoughlin': [[1986, 19472057.0]],
#  'Jason Moore': [[2012, 115350426.0], [2016, 105011053.0]],
#  'David Anspaugh': [[1986, 28607524.0], [1993, 22750363.0]],
#  'Ami Canaan Mann': [[2011, 957240.0]],
#  'Vishnuvardhan': [[2013, 21000000.0]],
#  'Alejandro Agresti': [[2006, 114830111.0]],
#  'Christian Alvart': [[1985, 20645327.0], [2009, 29000000.0]],
#  'Rian Johnson': [[2005, 3919254.0], [2008, 5530764.0], [2012, 47042000.0]],
#  'Stewart Hendler': [[1999, 5285197.0], [2009, 0.0], [2016, 6272403.0]],
#  'Greg MacGillivray': [[1995, 87600000.0], [2002, 0.0]],
#  'Jim McBride': [[1983, 19910002.0]],
#  'Kat Coiro': [[2011, 30905.0], [2013, 4187.0]],
#  'John Hillcoat': [[1988, 5048693.0],
#   [2001, 0.0],
#   [2009, 27635305.0],
#   [2010, 0.0]],
#  'Karl Zwicky': [[1997, 1778391.0]],
#  'Benh Zeitlin': [[2012, 21107746.0]],
#  'Ari Folman': [[2008, 11125849.0], [2013, 455815.0]],
#  'Pedro Almod√≥var': [[1978, 706685.0],
#   [1985, 1710057.0],
#   [1997, 1535558.0],
#   [1999, 67872296.0],
#   [2001, 0.0],
#   [2004, 40266982.0],
#   [2010, 0.0],
#   [2011, 0.0],
#   [2015, 0.0],
#   [2015, 11724119.0]],
#  'David Mirkin': [[1997, 29235353.0]],
#  'Terence Fisher': [[1966, 364937.0]],
#  'Dave Green': [[2015, 0.0], [2016, 245623848.0]],
#  'Sean Garrity': [[2012, 45250.0], [2012, 161820.0]],
#  'Adam Shankman': [[1976, 0.0],
#   [2001, 47494916.0],
#   [2003, 132675402.0],
#   [2005, 113006880.0],
#   [2005, 0.0],
#   [2006, 94728529.0],
#   [2007, 212874442.0]],
#  'Jon Turteltaub': [[1987, 134402450.0],
#   [1993, 154864401.0],
#   [1996, 152036382.0],
#   [1997, 0.0],
#   [2004, 347451894.0],
#   [2007, 457363168.0],
#   [2009, 182057016.0],
#   [2010, 215283742.0]],
#  'Ken Russell': [[1975, 0.0],
#   [1988, 331000.0],
#   [2009, 0.0],
#   [2012, 1189315.0],
#   [2017, 19853892.0]],
#  'Andrey Kravchuk': [[2008, 38135878.0]],
#  'Adrian Lyne': [[1986, 0.0],
#   [1987, 320145693.0],
#   [1989, 266614059.0],
#   [1997, 1060056.0],
#   [2001, 4400000.0],
#   [2002, 119137784.0],
#   [2005, 92921203.0],
#   [2010, 0.0]],
#  'Jeff Burr': [[1983, 1400000.0], [1989, 1519796.0], [1990, 5765562.0]],
#  'Paul Greengrass': [[2002, 773228.0],
#   [2002, 0.0],
#   [2004, 288500217.0],
#   [2006, 76286096.0],
#   [2010, 94882889.0],
#   [2013, 95000000.0]],
#  'Christopher McQuarrie': [[2000, 19125401.0],
#   [2012, 218340595.0],
#   [2013, 682330139.0]],
#  'Kinka Usher': [[1999, 29762011.0]],
#  'Costa-Gavras': [[1969, 0.0],
#   [1982, 14000000.0],
#   [1989, 6263883.0],
#   [1992, 114247.0],
#   [1997, 10541523.0]],
#  'Javier C√°rdenas': [[2004, 928391.0]],
#  'Chris Fisher': [[2009, 4100000.0], [2012, 525.0]],
#  'Alex Rivera': [[2008, 107559.0]],
#  'Michael Lehmann': [[1988, 1108462.0],
#   [1991, 17218080.0],
#   [1991, 485772.0],
#   [1998, 7985929.0],
#   [2011, 69485490.0]],
#  'Bernardo Bertolucci': [[1972, 36144000.0],
#   [1987, 43984230.0],
#   [1992, 0.0],
#   [2008, 2075084.0],
#   [2011, 15121165.0]],
#  'Mel Damski': [[1985, 8692426.0], [2010, 4300000.0]],
#  'Michael Addis': [[2000, 1404.0]],
#  'Rick Jacobson': [[2009, 199436.0]],
#  'Steven Soderbergh': [[1983, 33372606.0],
#   [1992, 137551594.0],
#   [1993, 362744280.0],
#   [1998, 77745568.0],
#   [1998, 15600000.0],
#   [1999, 3193102.0],
#   [2000, 207515725.0],
#   [2001, 450717150.0],
#   [2002, 2506446.0],
#   [2002, 30002758.0],
#   [2004, 5914908.0],
#   [2007, 311312624.0],
#   [2007, 63372757.0],
#   [2009, 1007962.0],
#   [2009, 35424826.0],
#   [2011, 256271286.0],
#   [2014, 167221571.0]],
#  'Pierre Morel': [[1979, 52826594.0],
#   [1979, 226830568.0],
#   [2004, 9584131.0],
#   [2008, 13644292.0]],
#  'Arthur Hiller': [[1970, 136400000.0],
#   [1976, 51079064.0],
#   [1992, 17530973.0],
#   [2008, 45779.0],
#   [2010, 38200000.0],
#   [2017, 46908987.0]],
#  'Michael Radford': [[2007, 6819587.0]],
#  'Stephen Chow': [[2001, 42776760.0],
#   [2001, 553810228.0],
#   [2004, 100914445.0],
#   [2008, 47301471.0]],
#  'Galt Niederhoffer': [[2010, 123820.0]],
#  'Betsy Chasse': [[2004, 10000000.0], [2006, 138913.0]],
#  'Tommy Wirkola': [[2009, 1984662.0], [2013, 224803475.0], [2014, 37473.0]],
#  'Drake Doremus': [[2013, 15000.0], [2013, 3542353.0], [2016, 2084628.0]],
#  'Luc Dardenne': [[1952, 266665.0], [2010, 0.0], [2014, 6860853.0]],
#  'John A. Davis': [[2001, 80936232.0], [2006, 55181129.0]],
#  'Ned Benson': [[2014, 985007.0]],
#  'Shawn Levy': [[1939, 190212113.0],
#   [2001, 152263880.0],
#   [2002, 52970014.0],
#   [2007, 0.0],
#   [2008, 413106170.0],
#   [2010, 574480841.0],
#   [2013, 44000000.0],
#   [2014, 41296320.0],
#   [2015, 349424282.0]],
#  'Deborah Scranton': [[2006, 254190.0]],
#  'Giuliano Carnimeo': [[1983, 606694.0]],
#  'Danny Huston': [[1988, 1221366.0]],
#  'Jeff Tremaine': [[1984, 0.0],
#   [2006, 72778712.0],
#   [2010, 117224271.0],
#   [2013, 0.0]],
#  '√Ålex de la Iglesia': [[1995, 4367497.0], [2010, 3218666.0]],
#  'Bill Pohlad': [[2015, 28641776.0]],
#  'Alex Garland': [[2015, 36869414.0]],
#  'Philippe Caland': [[2014, 1189612.0]],
#  'Jan Verheyen': [[2007, 1.0], [2010, 3082901.0]],
#  'Nancy Meyers': [[1999, 219103655.0],
#   [2000, 374111707.0],
#   [2003, 266728738.0],
#   [2006, 194168700.0],
#   [2015, 194564672.0]],
#  'Nigel Cole': [[2000, 26330482.0], [2005, 42886719.0], [2017, 96542059.0]],
#  'Wu Jing': [[2015, 80000000.0]],
#  'Christian Ditter': [[2009, 4439431.0], [2016, 112343513.0]],
#  'Francis Veber': [[1989, 40590000.0],
#   [1999, 1659542.0],
#   [2006, 29326868.0],
#   [2014, 0.0]],
#  '√Ålvaro S√°enz de Heredia': [[1989, 0.0], [1991, 3370574.0]],
#  'Dominique Deruddere': [[1987, 119919.0]],
#  'George Clooney': [[2002, 33013805.0],
#   [2003, 0.0],
#   [2005, 54600000.0],
#   [2011, 75993061.0],
#   [2011, 154984035.0]],
#  'Ben Stassen': [[2004, 13651656.0], [2016, 3342697.0]],
#  'Vladimir Grammatikov': [[1987, 2300000.0]],
#  'Sergei Bodrov': [[2013, 26527510.0], [2014, 114178613.0]],
#  'Tom Holland': [[1983, 24922237.0], [1988, 44196684.0]],
#  'Michael Austin': [[1994, 3021629.0]],
#  'Jonathan Levine': [[1995, 0.0],
#   [1996, 0.0],
#   [2008, 2899975.0],
#   [2013, 116980662.0],
#   [2017, 60845711.0]],
#  'Paco Plaza': [[2009, 18469680.0], [2011, 0.0]],
#  'Roger Donaldson': [[1984, 8613462.0],
#   [1986, 0.0],
#   [1994, 30.0],
#   [1995, 113374103.0],
#   [1997, 178127760.0],
#   [2001, 0.0],
#   [2003, 101191884.0],
#   [2010, 0.0],
#   [2011, 12355798.0],
#   [2011, 171504781.0],
#   [2014, 32556119.0],
#   [2014, 0.0]],
#  'Lewis Gilbert': [[1967, 111584787.0],
#   [1977, 185438673.0],
#   [1984, 210308099.0]],
#  'Frederik Du Chau': [[1991, 93772522.0], [1998, 38172500.0]],
#  'Peter Farrelly': [[1988, 127766650.0],
#   [1994, 0.0],
#   [1995, 0.0],
#   [2000, 369884651.0],
#   [2001, 141069860.0],
#   [2007, 0.0],
#   [2012, 54819301.0]],
#  'Michael Ritchie': [[1985, 59612888.0],
#   [1989, 35150960.0],
#   [1992, 79817939.0],
#   [2006, 4836637.0],
#   [2007, 0.0],
#   [2008, 0.0]],
#  'Galen T. Chu': [[2016, 408579038.0]],
#  'Lee Tamahori': [[1997, 43312294.0],
#   [2001, 105178561.0],
#   [2002, 431971116.0],
#   [2005, 71073932.0],
#   [2005, 5728213.0],
#   [2007, 76066841.0],
#   [2012, 0.0]],
#  'Joss Whedon': [[1990, 0.0],
#   [2001, 38869464.0],
#   [2012, 1519557910.0],
#   [2015, 1405403694.0]],
#  'John Bruno': [[1999, 14010690.0]],
#  'Rob Bowman': [[1983, 189198313.0],
#   [1993, 2850263.0],
#   [2000, 82150183.0],
#   [2005, 56681566.0]],
#  'Maren Ade': [[2016, 1390172.0]],
#  'Kimberly Peirce': [[1995, 11207130.0],
#   [1999, 11540607.0],
#   [2013, 82394288.0]],
#  'Denys Arcand': [[2007, 0.0], [2014, 40000.0]],
#  'Andrew Morahan': [[1994, 36800000.0]],
#  'Scott Cooper': [[1985, 98837872.0], [2009, 47405566.0], [2013, 15400000.0]],
#  'Roberto Benigni': [[1997, 229400000.0], [2013, 41323171.0]],
#  'Hong Sang-soo': [[2011, 11.0]],
#  'Michael Curtiz': [[1936, 2736000.0],
#   [1942, 10462500.0],
#   [2002, 0.0],
#   [2003, 5638000.0]],
#  'Jordan Rubin': [[2014, 14947.0]],
#  'Michael Lembeck': [[2004, 11341016.0],
#   [2006, 84500122.0],
#   [2006, 172842355.0],
#   [2010, 112462508.0]],
#  'Rory Kelly': [[1994, 161410.0]],
#  'Andrea Arnold': [[1968, 0.0],
#   [2008, 1128345.0],
#   [2009, 2357852.0],
#   [2016, 1751330.0]],
#  'Jan Ole Gerster': [[2012, 2750275.0]],
#  'Stanley Kubrick': [[1960, 60000000.0],
#   [1962, 9250000.0],
#   [1964, 0.0],
#   [1971, 26589000.0],
#   [1996, 0.0],
#   [1999, 162091208.0],
#   [2002, 68700000.0],
#   [2014, 0.0],
#   [2016, 20000000.0]],
#  'Richard Attenborough': [[1977, 50750000.0],
#   [1982, 77737889.0],
#   [1985, 14202899.0]],
#  'David Mackenzie': [[1963, 0.0],
#   [1987, 908000.0],
#   [2001, 54915.0],
#   [2003, 2500000.0],
#   [2004, 37589296.0],
#   [2007, 60641.0]],
#  'Mike Mills': [[2005, 1919197.0], [2010, 5332926.0], [2013, 5664764.0]],
#  'Dana Adam Shapiro': [[2005, 1750211.0]],
#  'Sangyoon Lim': [[2012, 7339398.0]],
#  'Thor Freudenthal': [[1992, 117000198.0], [1999, 0.0], [2013, 174578751.0]],
#  'Duncan Jones': [[2009, 9760104.0], [2011, 147332697.0], [2016, 433677183.0]],
#  'F.W. Murnau': [[2027, 121.0]],
#  'Mel Brooks': [[1974, 119500000.0],
#   [1974, 0.0],
#   [1977, 31063038.0],
#   [1987, 38119483.0],
#   [1993, 35739755.0],
#   [2004, 0.0]],
#  'Emile Ardolino': [[1987, 213954274.0], [1993, 2119994.0], [2010, 0.0]],
#  'Henry Hathaway': [[1953, 8500000.0], [1957, 2200000.0], [1969, 0.0]],
#  'Jon Cassar': [[2016, 30658387.0]],
#  'George Gallo': [[1994, 5777916.0], [2006, 32788.0]],
#  'Wilfred Jackson': [[1953, 87404651.0]],
#  'Ulu Grosbard': [[1984, 11129057.0], [1992, 28121100.0]],
#  'Rodney Ascher': [[2015, 28281.0]],
#  'Armando Iannucci': [[2009, 6149791.0]],
#  'Jonathan Demme': [[1970, 4978922.0],
#   [1986, 8362969.0],
#   [1988, 21486757.0],
#   [2003, 108282.0],
#   [2004, 96105964.0],
#   [2005, 272742922.0],
#   [2011, 206678440.0],
#   [2015, 41325328.0]],
#  'Norman Lear': [[1971, 11000000.0]],
#  'Carl Reiner': [[1958, 18196170.0],
#   [1978, 16928137.0],
#   [1985, 24689703.0],
#   [1987, 35114428.0],
#   [1993, 41687243.0],
#   [1999, 0.0]],
#  'Max Adams': [[2016, 100659.0]],
#  'Nick Ormerod': [[2012, 8303261.0]],
#  'Josh Boone': [[1986, 0.0], [2014, 307166834.0]],
#  'Wim Wenders': [[1972, 100.0],
#   [1984, 2181987.0],
#   [1987, 3200000.0],
#   [1993, 810455.0],
#   [2011, 14624826.0],
#   [2015, 8034.0]],
#  'Simon Klose': [[2013, 34664.0]],
#  'Clarence Brown': [[1936, 2019000.0], [1986, 0.0], [2015, 1439000.0]],
#  'Gwen Wetzler': [[1985, 7.0]],
#  'Edgar Wright': [[1998, 30332385.0],
#   [2009, 0.0],
#   [2011, 0.0],
#   [2013, 46089287.0],
#   [2017, 224511319.0]],
#  'Guy Ritchie': [[1935, 334615000.0],
#   [1996, 0.0],
#   [1998, 3897569.0],
#   [2000, 83557872.0],
#   [2002, 598645.0],
#   [2002, 0.0],
#   [2008, 25739015.0],
#   [2013, 108145109.0]],
#  'Nicholas Mastandrea': [[2006, 1675484.0]],
#  'Shekhar Kapur': [[1993, 74237563.0],
#   [1998, 82150642.0],
#   [2002, 29882645.0],
#   [2006, 399.0]],
#  'James Manera': [[2014, 846704.0]],
#  'James Fargo': [[1976, 46236000.0], [1978, 85.0], [2001, 6660333.0]],
#  'Lena Dunham': [[2010, 416498.0]],
#  'Ridley Scott': [[1979, 104931801.0],
#   [1985, 15502112.0],
#   [1988, 268031828.0],
#   [1992, 7191399.0],
#   [1996, 10278549.0],
#   [1996, 172989651.0],
#   [1997, 0.0],
#   [1999, 266465037.0],
#   [2000, 113280098.0],
#   [2001, 351692268.0],
#   [2002, 45892212.0],
#   [2002, 45361000.0],
#   [2003, 0.0],
#   [2005, 42064105.0],
#   [2010, 310669540.0],
#   [2011, 0.0],
#   [2012, 403170142.0],
#   [2012, 232380243.0],
#   [2012, 10300000.0],
#   [2012, 65565672.0],
#   [2013, 71009334.0],
#   [2014, 32868943.0],
#   [2015, 630161890.0]],
#  'Bharathan': [[2017, 17000000.0]],
#  'Joseph Sargent': [[1987, 51881013.0], [1996, 6670680.0]],
#  'David Dobkin': [[1988, 88323487.0],
#   [2005, 285176741.0],
#   [2007, 97838349.0],
#   [2011, 75450437.0],
#   [2014, 83719388.0]],
#  'Olivier Assayas': [[1970, 85154.0],
#   [2010, 871279.0],
#   [2014, 1851517.0],
#   [2016, 1305195.0]],
#  'John Sayles': [[1996, 13269963.0], [2008, 0.0], [2009, 0.0]],
#  'Christian Charles': [[2002, 2744253.0]],
#  'Josh Radnor': [[2004, 327345.0], [2010, 215576.0]],
#  'Susanna White': [[2012, 93246388.0], [2016, 9930095.0]],
#  'Robert M. Young': [[1986, 13418091.0]],
#  'Jay Roach': [[1987, 8235661.0],
#   [1993, 0.0],
#   [1999, 8888143.0],
#   [2000, 330444045.0],
#   [2005, 516642939.0],
#   [2012, 0.0],
#   [2013, 296655431.0],
#   [2014, 312016858.0],
#   [2016, 0.0]],
#  'Joshua Seftel': [[2008, 1296184.0]],
#  'Peter Atencio': [[2016, 20566327.0]],
#  'Brad Lewis': [[2011, 559852396.0]],
#  'Jason Friedberg': [[1958, 14109284.0],
#   [1991, 0.0],
#   [2003, 48548426.0],
#   [2008, 84646831.0],
#   [2010, 80547866.0]],
#  'Dean Israelite': [[2015, 32248241.0], [2017, 142337240.0]],
#  'Jean-Fran√ßois Pouliot': [[2014, 223003.0]],
#  'David R. Ellis': [[1996, 32709423.0],
#   [2003, 90426405.0],
#   [2004, 56422687.0],
#   [2006, 62022014.0],
#   [2011, 10126458.0],
#   [2011, 186167139.0]],
#  'Oren Peli': [[2007, 193355800.0]],
#  'Kari Skogland': [[2007, 473993.0]],
#  'David Seltzer': [[1986, 8200000.0], [1988, 21032267.0], [1992, 21621000.0]],
#  'James Mangold': [[2003, 90259536.0],
#   [2005, 186438883.0],
#   [2012, 44862187.0],
#   [2012, 70016220.0],
#   [2013, 415440673.0],
#   [2013, 261930431.0]],
#  'Massy Tadjedin': [[2010, 7644937.0]],
#  'Eli Roth': [[1997, 6833445.0],
#   [1999, 0.0],
#   [2001, 35619521.0],
#   [2003, 30553394.0],
#   [2015, 6341684.0]],
#  'Ben Lewin': [[2012, 9138338.0]],
#  'Ashish R. Mohan': [[2012, 126.0]],
#  'Jonathan Frakes': [[1989, 0.0],
#   [2002, 38793283.0],
#   [2004, 0.0],
#   [2008, 118000000.0]],
#  'Alfonso Cuar√≥n': [[1998, 55494066.0],
#   [2001, 33616692.0],
#   [2008, 69959751.0],
#   [2013, 716392705.0],
#   [2015, 0.0]],
#  'Marc Rocco': [[1995, 17381942.0]],
#  'Leslie Greif': [[1997, 57252.0]],
#  'Olivier Masset-Depasse': [[2010, 404.0]],
#  'Enzo G. Castellari': [[1975, 39598448.0]],
#  'Peter Masterson': [[1985, 7218340.0], [1989, 337812.0]],
#  'Roger Avary': [[1993, 418961.0]],
#  'Jeff Nichols': [[2000, 21587700.0],
#   [2011, 3099314.0],
#   [2016, 6212282.0],
#   [2016, 8996802.0]],
#  'Fran√ßois Ozon': [[2003, 0.0],
#   [2012, 11879046.0],
#   [2015, 1611000.0],
#   [2015, 880474.0]],
#  ...}

# %%
testD = 'Ken Kwapis'
testDate = 2007
print(getDirectorSuccess(testD, testDate))
meme = directorsAndMovies[testD]
av = meme[0][1] + meme[1][1] + meme[2][1]
print(av/3)
# Out:
# 84101196.33333333
# 84101196.33333333

# %%
for movie in directorsAndMovies[testD]:
    print(type(movie[0]))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
import statistics
def getDirectorSuccess(director, date):
    relevantList = []
    if director == None:
        return 0
    for movie in directorsAndMovies[director]:
        if int(movie[0]) < date:
            relevantList.append(movie[1])
        else:
            break
    if len(relevantList) == 0:
        return 0
    return statistics.mean(relevantList)

# %%
combined['directorSucess'] = combined.apply(lambda row: getDirectorSuccess(row.rel_crew['Director'], int(row.release_date[-4:])) if row.release_date != 'nan' and 'Director' in row.rel_crew.keys() and type(row.release_date) == str else 0, axis = 1)

# %%
type(int(combined.iloc[4397]['release_date'][-4:]))
getDirectorSuccess(combined.iloc[4397]['rel_crew']['Director'], 2005)
# Out:
# 35235789.5

# %%
combined
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                  0   3300000
# 3        4                                                  0   1200000
# 4        5                                                  0         0
# ...    ...                                                ...       ...
# 4393  7394                                                  0  42000000
# 4394  7395  [{'id': 146534, 'name': 'Without a Paddle Coll...  19000000
# 4395  7396                                                  0  16000000
# 4396  7397                                                  0   2000000
# 4397  7398                                                  0     64000
#
#                                                  genres original_language  \
# 0                        [{'id': 35, 'name': 'Comedy'}]                en
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 2                         [{'id': 18, 'name': 'Drama'}]                en
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...                hi
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...                ko
# ...                                                 ...               ...
# 4393                   [{'id': 53, 'name': 'Thriller'}]                en
# 4394  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 4395                      [{'id': 18, 'name': 'Drama'}]                en
# 4396  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...                en
# 4397                      [{'id': 18, 'name': 'Drama'}]                fr
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 4393                              Original Sin
# 4394                          Without a Paddle
# 4395                               The Verdict
# 4396                                It Follows
# 4397      Vivre sa vie: film en douze tableaux
#
#                                    production_companies  \
# 0     [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1           [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2     [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4393  [{'name': 'Intermedia Films', 'id': 763}, {'na...
# 4394  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4395  [{'name': 'Twentieth Century Fox Film Corporat...
# 4396  [{'name': 'Northern Lights Films', 'id': 8714}...
# 4397  [{'name': 'Pathé Consortium Cinéma', 'id': 220...
#
#                                    production_countries release_date  runtime  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...    2/20/2015     93.0
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...     8/6/2004    113.0
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   10/10/2014    105.0
# 3               [{'iso_3166_1': 'IN', 'name': 'India'}]     3/9/2012    122.0
# 4         [{'iso_3166_1': 'KR', 'name': 'South Korea'}]     2/5/2009    118.0
# ...                                                 ...          ...      ...
# 4393  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...    8/20/2004    118.0
# 4394  [{'iso_3166_1': 'US', 'name': 'United States o...    12/8/1982     95.0
# 4395  [{'iso_3166_1': 'US', 'name': 'United States o...     2/4/2015    129.0
# 4396  [{'iso_3166_1': 'US', 'name': 'United States o...    9/20/1962    100.0
# 4397           [{'iso_3166_1': 'FR', 'name': 'France'}]          NaN     85.0
#
#       ...                                           Keywords  \
# 0     ...  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     ...  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     ...  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     ...  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4     ...                                                NaN
# ...   ...                                                ...
# 4393  ...  [{'id': 515, 'name': 'women'}, {'id': 572, 'na...
# 4394  ...  [{'id': 4959, 'name': 'death of a friend'}, {'...
# 4395  ...  [{'id': 1680, 'name': 'boston'}, {'id': 6148, ...
# 4396  ...  [{'id': 3713, 'name': 'chase'}, {'id': 6152, '...
# 4397  ...  [{'id': 90, 'name': 'paris'}, {'id': 490, 'nam...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 4393  [{'cast_id': 17, 'character': 'Julia Russell/B...
# 4394  [{'cast_id': 40, 'character': 'Dan Mott', 'cre...
# 4395  [{'cast_id': 1, 'character': 'Frank Galvin', '...
# 4396  [{'cast_id': 1, 'character': 'Jay Height', 'cr...
# 4397  [{'cast_id': 8, 'character': 'Nana Kleinfranke...
#
#                                                    crew   revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# ...                                                 ...       ...
# 4393  [{'credit_id': '52fe4330c3a36847f80412db', 'de...  35402320
# 4394  [{'credit_id': '52fe43b29251416c7501a909', 'de...  69631118
# 4395  [{'credit_id': '52fe448bc3a368484e028c55', 'de...  53977250
# 4396  [{'credit_id': '537770b20e0a261431002299', 'de...  14674076
# 4397  [{'credit_id': '52fe4306c3a36847f80349a5', 'de...     24517
#
#      has_collection                                         collection  \
# 0                 1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1                 1  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2                 0                                                  0
# 3                 0                                                  0
# 4                 0                                                  0
# ...             ...                                                ...
# 4393              0                                                  0
# 4394              1  [{'id': 146534, 'name': 'Without a Paddle Coll...
# 4395              0                                                  0
# 4396              0                                                  0
# 4397              0                                                  0
#
#                       collection_name  \
# 0     Hot Tub Time Machine Collection
# 1     The Princess Diaries Collection
# 2                                   0
# 3                                   0
# 4                                   0
# ...                               ...
# 4393                                0
# 4394      Without a Paddle Collection
# 4395                                0
# 4396                                0
# 4397                                0
#
#                                              rel_actors  \
# 0     {'actor1': 'Rob Corddry', 'actor2': 'Craig Rob...
# 1     {'actor1': 'Anne Hathaway', 'actor2': 'Julie A...
# 2     {'actor1': 'Miles Teller', 'actor2': 'J.K. Sim...
# 3     {'actor1': 'Vidya Balan', 'actor2': 'Nawazuddi...
# 4     {'actor1': 'Kim Kang-woo', 'actor2': 'Jo Jae-h...
# ...                                                 ...
# 4393  {'actor1': 'Angelina Jolie', 'actor2': 'Antoni...
# 4394  {'actor1': 'Seth Green', 'actor2': 'Matthew Li...
# 4395  {'actor1': 'Paul Newman', 'actor2': 'Charlotte...
# 4396  {'actor1': 'Maika Monroe', 'actor2': 'Keir Gil...
# 4397  {'actor1': 'Anna Karina', 'actor2': 'Sady Rebb...
#
#                                                rel_crew directorSucess
# 0     {'Director': 'Steve Pink', 'Producer': 'Andrew...   5.069332e+07
# 1     {'Director': 'Garry Marshall', 'Producer': 'Wh...   1.138730e+08
# 2     {'Director': 'Damien Chazelle', 'Producer': 'J...   4.454357e+08
# 3     {'Director': 'Sujoy Ghosh', 'Producer': 'Sujoy...   0.000000e+00
# 4      {'Director': 'Jong-seok Yoon', 'Producer': None}   0.000000e+00
# ...                                                 ...            ...
# 4393  {'Director': 'Michael Cristofer', 'Producer': ...   2.398940e+05
# 4394  {'Director': 'Steven Brill', 'Producer': 'Dona...   0.000000e+00
# 4395  {'Director': 'Sidney Lumet', 'Producer': 'Rich...   1.902915e+07
# 4396  {'Director': 'David Robert Mitchell', 'Produce...   0.000000e+00
# 4397  {'Director': 'Jean-Luc Godard', 'Producer': 'P...   0.000000e+00
#
# [7398 rows x 22 columns]

# %%
result
# Out:
#                    Director     revenue  date
# 0                Steve Pink  12314651.0  2015
# 1            Garry Marshall  95149435.0  2004
# 2           Damien Chazelle  13092000.0  2014
# 3               Sujoy Ghosh  16000000.0  2012
# 4            Jong-seok Yoon   3923970.0  2009
# ...                     ...         ...   ...
# 4393      Michael Cristofer  35402320.0  2004
# 4394           Steven Brill  69631118.0  1982
# 4395           Sidney Lumet  53977250.0  2015
# 4396  David Robert Mitchell  14674076.0  1962
# 4397        Jean-Luc Godard     24517.0   nan
#
# [7398 rows x 3 columns]

# %%
combined
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                  0   3300000
# 3        4                                                  0   1200000
# 4        5                                                  0         0
# ...    ...                                                ...       ...
# 4393  7394                                                  0  42000000
# 4394  7395  [{'id': 146534, 'name': 'Without a Paddle Coll...  19000000
# 4395  7396                                                  0  16000000
# 4396  7397                                                  0   2000000
# 4397  7398                                                  0     64000
#
#                                                  genres original_language  \
# 0                        [{'id': 35, 'name': 'Comedy'}]                en
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 2                         [{'id': 18, 'name': 'Drama'}]                en
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...                hi
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...                ko
# ...                                                 ...               ...
# 4393                   [{'id': 53, 'name': 'Thriller'}]                en
# 4394  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 4395                      [{'id': 18, 'name': 'Drama'}]                en
# 4396  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...                en
# 4397                      [{'id': 18, 'name': 'Drama'}]                fr
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 4393                              Original Sin
# 4394                          Without a Paddle
# 4395                               The Verdict
# 4396                                It Follows
# 4397      Vivre sa vie: film en douze tableaux
#
#                                    production_companies  \
# 0     [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1           [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2     [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4393  [{'name': 'Intermedia Films', 'id': 763}, {'na...
# 4394  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4395  [{'name': 'Twentieth Century Fox Film Corporat...
# 4396  [{'name': 'Northern Lights Films', 'id': 8714}...
# 4397  [{'name': 'Pathé Consortium Cinéma', 'id': 220...
#
#                                    production_countries release_date  runtime  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...    2/20/2015     93.0
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...     8/6/2004    113.0
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   10/10/2014    105.0
# 3               [{'iso_3166_1': 'IN', 'name': 'India'}]     3/9/2012    122.0
# 4         [{'iso_3166_1': 'KR', 'name': 'South Korea'}]     2/5/2009    118.0
# ...                                                 ...          ...      ...
# 4393  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...    8/20/2004    118.0
# 4394  [{'iso_3166_1': 'US', 'name': 'United States o...    12/8/1982     95.0
# 4395  [{'iso_3166_1': 'US', 'name': 'United States o...     2/4/2015    129.0
# 4396  [{'iso_3166_1': 'US', 'name': 'United States o...    9/20/1962    100.0
# 4397           [{'iso_3166_1': 'FR', 'name': 'France'}]          NaN     85.0
#
#       ...                                     title  \
# 0     ...                    Hot Tub Time Machine 2
# 1     ...  The Princess Diaries 2: Royal Engagement
# 2     ...                                  Whiplash
# 3     ...                                   Kahaani
# 4     ...                                Marine Boy
# ...   ...                                       ...
# 4393  ...                              Original Sin
# 4394  ...                          Without a Paddle
# 4395  ...                               The Verdict
# 4396  ...                                It Follows
# 4397  ...                              Vivre Sa Vie
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# ...                                                 ...
# 4393  [{'id': 515, 'name': 'women'}, {'id': 572, 'na...
# 4394  [{'id': 4959, 'name': 'death of a friend'}, {'...
# 4395  [{'id': 1680, 'name': 'boston'}, {'id': 6148, ...
# 4396  [{'id': 3713, 'name': 'chase'}, {'id': 6152, '...
# 4397  [{'id': 90, 'name': 'paris'}, {'id': 490, 'nam...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 4393  [{'cast_id': 17, 'character': 'Julia Russell/B...
# 4394  [{'cast_id': 40, 'character': 'Dan Mott', 'cre...
# 4395  [{'cast_id': 1, 'character': 'Frank Galvin', '...
# 4396  [{'cast_id': 1, 'character': 'Jay Height', 'cr...
# 4397  [{'cast_id': 8, 'character': 'Nana Kleinfranke...
#
#                                                    crew   revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# ...                                                 ...       ...
# 4393  [{'credit_id': '52fe4330c3a36847f80412db', 'de...  35402320
# 4394  [{'credit_id': '52fe43b29251416c7501a909', 'de...  69631118
# 4395  [{'credit_id': '52fe448bc3a368484e028c55', 'de...  53977250
# 4396  [{'credit_id': '537770b20e0a261431002299', 'de...  14674076
# 4397  [{'credit_id': '52fe4306c3a36847f80349a5', 'de...     24517
#
#       has_collection                                         collection  \
# 0                  1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1                  1  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2                  0                                                  0
# 3                  0                                                  0
# 4                  0                                                  0
# ...              ...                                                ...
# 4393               0                                                  0
# 4394               1  [{'id': 146534, 'name': 'Without a Paddle Coll...
# 4395               0                                                  0
# 4396               0                                                  0
# 4397               0                                                  0
#
#                       collection_name  \
# 0     Hot Tub Time Machine Collection
# 1     The Princess Diaries Collection
# 2                                   0
# 3                                   0
# 4                                   0
# ...                               ...
# 4393                                0
# 4394      Without a Paddle Collection
# 4395                                0
# 4396                                0
# 4397                                0
#
#                                              rel_actors  \
# 0     {'actor1': 'Rob Corddry', 'actor2': 'Craig Rob...
# 1     {'actor1': 'Anne Hathaway', 'actor2': 'Julie A...
# 2     {'actor1': 'Miles Teller', 'actor2': 'J.K. Sim...
# 3     {'actor1': 'Vidya Balan', 'actor2': 'Nawazuddi...
# 4     {'actor1': 'Kim Kang-woo', 'actor2': 'Jo Jae-h...
# ...                                                 ...
# 4393  {'actor1': 'Angelina Jolie', 'actor2': 'Antoni...
# 4394  {'actor1': 'Seth Green', 'actor2': 'Matthew Li...
# 4395  {'actor1': 'Paul Newman', 'actor2': 'Charlotte...
# 4396  {'actor1': 'Maika Monroe', 'actor2': 'Keir Gil...
# 4397  {'actor1': 'Anna Karina', 'actor2': 'Sady Rebb...
#
#                                                rel_crew
# 0     {'Director': 'Steve Pink', 'Producer': 'Andrew...
# 1     {'Director': 'Garry Marshall', 'Producer': 'Wh...
# 2     {'Director': 'Damien Chazelle', 'Producer': 'J...
# 3     {'Director': 'Sujoy Ghosh', 'Producer': 'Sujoy...
# 4      {'Director': 'Jong-seok Yoon', 'Producer': None}
# ...                                                 ...
# 4393  {'Director': 'Michael Cristofer', 'Producer': ...
# 4394  {'Director': 'Steven Brill', 'Producer': 'Dona...
# 4395  {'Director': 'Sidney Lumet', 'Producer': 'Rich...
# 4396  {'Director': 'David Robert Mitchell', 'Produce...
# 4397  {'Director': 'Jean-Luc Godard', 'Producer': 'P...
#
# [7398 rows x 21 columns]
